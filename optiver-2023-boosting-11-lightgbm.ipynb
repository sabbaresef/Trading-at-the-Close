# %%
import warnings
warnings.filterwarnings("ignore")
from itertools import combinations

import gc
import os
import sys
import json

import numpy as np
import pandas as pd
import numba as nb
import polars as pl
import lightgbm as lgb

from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Functions

# %%
@nb.jit(nopython=False, parallel=True)
def reduce_mem_usage(df):
    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float32)
        
    return df


@nb.jit(nopython=False, parallel=True)
def compute_triplet_imbalance(df_values, comb_indices):
    num_rows = df_values.shape[0]
    num_combinations = len(comb_indices)
    imbalance_features = np.empty((num_rows, num_combinations))
    for i in range(num_combinations):
        a, b, c = comb_indices[i]
        for j in range(num_rows):
            max_val = max(df_values[j, a], df_values[j, b], df_values[j, c])
            min_val = min(df_values[j, a], df_values[j, b], df_values[j, c])
            mid_val = df_values[j, a] + df_values[j, b] + df_values[j, c] - min_val - max_val
            
            if mid_val == min_val:
                imbalance_features[j, i] = np.nan
            else:
                imbalance_features[j, i] = (max_val - mid_val) / (mid_val - min_val)
    return imbalance_features


@nb.jit(nopython=False, fastmath=True)
def calculate_triplet_imbalance(price, df):
    df_values = df[price].values
    comb_indices = [(price.index(a), price.index(b), price.index(c)) for a, b, c in combinations(price, 3)]
    features_array = compute_triplet_imbalance(df_values, comb_indices)
    columns = [f"{a}_{b}_{c}_imb2" for a, b, c in combinations(price, 3)]
    features = pd.DataFrame(features_array, columns=columns)
    return features


@nb.jit(nopython=False, parallel=True)
def calculate_weighted_wap(df):
    df["stock_weights"] = df["stock_id"].map(weights)
    df["weighted_wap"] = df["stock_weights"] * df["wap"]
    df['wap_momentum'] = df.groupby('stock_id')['weighted_wap'].pct_change(periods=6)
    return df


@nb.jit(nopython=False, parallel=True)
def calculate_rolling_mean_and_std_expressions(df):
    # Convert from pandas to Polars
    pl_df = pl.from_pandas(df)

    # Define the windows and columns for which you want to calculate the rolling statistics
    windows = [3, 5, 10]
    columns = ['ask_price', 'bid_price', 'ask_size', 'bid_size']

    # prepare the operations for each column and window
    group = ["stock_id"]
    expressions = []

    # Loop over each window and column to create the rolling mean and std expressions
    for window in windows:
        for col in columns:
            rolling_mean_expr = (
                pl.col(f"{col}_diff_{window}")
                .rolling_mean(window)
                .over(group)
                .alias(f'rolling_diff_{col}_{window}')
            )

            rolling_std_expr = (
                pl.col(f"{col}_diff_{window}")
                .rolling_std(window)
                .over(group)
                .alias(f'rolling_std_diff_{col}_{window}')
            )

            expressions.append(rolling_mean_expr)
            expressions.append(rolling_std_expr)

    # Run the operations using Polars' lazy API
    lazy_df = pl_df.lazy().with_columns(expressions)

    # Execute the lazy expressions and overwrite the pl_df variable
    pl_df = lazy_df.collect()

    # Convert back to pandas if necessary
    df = pl_df.to_pandas()
    
    return df

@nb.jit(nopython=False, parallel=True)
def calculate_diff_features(df):
    # Calculate diff features for specific columns
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap', 'ask_size', 'bid_size', 'weighted_wap', 'price_spread']:
        for window in [3, 5, 10]: # 2
            df[f"{col}_diff_{window}"] = df.groupby(["stock_id", "date_id"])[col].diff(window)
    return df
    
    
@nb.jit(nopython=False, parallel=True)
def calculate_gain_loss_features(df):
    window = 5
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap']:
        df[f"{col}_gain"] = df[f"{col}_diff_{window}"].where(df[f"{col}_diff_{window}"] > 0, 0)
        df[f"{col}_loss"] = df[f"{col}_diff_{window}"].where(df[f"{col}_diff_{window}"] < 0, 0)
        df[f"{col}_gain_avg"] = df[f"{col}_gain"].rolling(window=window).mean()
        df[f"{col}_loss_avg"] = df[f"{col}_loss"].rolling(window=window).mean()
    return df


@nb.jit(nopython=False, parallel=True)
def calculate_norm_features(df):
    grouped = df.groupby(["stock_id", "date_id"])
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap']:
        df[f"{col}_cummax"] = grouped[col].cummax() 
        df[f"{col}_cummin"] = grouped[col].cummin() 
        df[f"{col}_min_max_norm"] = df.eval(f'({col} - {col}_cummin) / ({col}_cummax - {col}_cummin)')
        
    columns_to_keep = [col for col in df.columns if 'cummax' not in col]
    df = df[columns_to_keep]
    columns_to_keep = [col for col in df.columns if 'cummin' not in col]
    df = df[columns_to_keep]
    
    return df
    
@nb.jit(nopython=False, parallel=True)
def calculate_bollinger(df):
    # Bollinger Bands 
    periods = [3, 5, 7, 9]
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap']:
        grouped = df.groupby(["stock_id", "date_id"])[col]
        for p in periods: 
            grouped_std = grouped.rolling(window=p).std().reset_index(drop=True)            
            df[f"{col}_bollinger_upper_{p}"] = df[f"{col}"] + 2 * grouped_std
            df[f"{col}_bollinger_lower_{p}"] = df[f"{col}"] - 2 * grouped_std
    return df


@nb.jit(nopython=False, parallel=True)
def calculate_diff_2_features(df):
    for window in [3, 5, 10]:
        df[f'price_change_diff_{window}'] = df[f'bid_price_diff_{window}'] - df[f'ask_price_diff_{window}']
        df[f'size_change_diff_{window}'] = df[f'bid_size_diff_{window}'] - df[f'ask_size_diff_{window}']
    return df
        

@nb.jit(nopython=False, parallel=True)
def calculate_all_prices_and_sizes_features(df, prices, sizes):
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
    return df


@nb.jit(nopython=False, parallel=True)
def calculate_pct_change_features(df, prices):
    for i in range(len(prices)-1):
        p1 = prices[i]
        for j in range(i+1, len(prices)):
            p2 = prices[j]
            df[f'{p1}_{p2}_pct_change'] = ((df[p1] - df[p2]) / df[p2]) * 100
    return df


@nb.jit(nopython=False, parallel=True)
def compute_combination_features(df, prices):
    for c in combinations(prices, 2):
        # df[f'{c[0]}_minus_{c[1]}'] = df[f'{c[0]}'] - df[f'{c[1]}']
        df[f'{c[0]}_{c[1]}_imb'] = df.eval(f'({c[0]} - {c[1]}) / ({c[0]} + {c[1]})')
        # df[f'{c[0]}_{c[1]}_urgency'] = df[f'{c[0]}_minus_{c[1]}'] * df['imb_s1']
    # columns_to_keep = [col for col in df.columns if 'minus' not in col]
    # df = df[columns_to_keep]
    return df
    


def feat_eng(df):   
    cols = [c for c in df.columns if c not in ['row_id', 'time_id', 'currently_scored']]
    df = df[cols]
    
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]
    prices = ['reference_price','far_price', 'near_price', 'ask_price', 'bid_price', 'wap']
    
    df = calculate_weighted_wap(df)
        
    # Adding some features
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  
    df["minute"] = df["seconds_in_bucket"] // 60
    df['time_to_market_close'] = 540 - df['seconds_in_bucket']
    
    df['imbalance_buy_flag'] = np.where(df['imbalance_buy_sell_flag']==1, 1, 0) 
    df['imbalance_sell_flag'] = np.where(df['imbalance_buy_sell_flag']==-1, 1, 0) 
    df['bid_plus_ask_sizes'] = df['bid_size'] + df['ask_size']
    df['imbalance_ratio'] = df.eval('imbalance_size / matched_size')
    
    df['imb_s1'] = df.eval('(bid_size - ask_size) / (bid_size + ask_size)')
    df['imb_s2'] = df.eval('(imbalance_size - matched_size) / (matched_size + imbalance_size)')
    
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["matched_imbalance"] = df.eval("(imbalance_size - matched_size)/(matched_size + imbalance_size)")
        
    df['ask_x_size'] = df.eval('ask_size * ask_price')
    df['bid_x_size'] = df.eval('bid_size * bid_price')
        
    df['ask_minus_bid'] = df['ask_x_size'] - df['bid_x_size'] 
    df["bid_size_over_ask_size"] = df["bid_size"].div(df["ask_size"])
    df["bid_price_over_ask_price"] = df["bid_price"].div(df["ask_price"])
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    df['relative_spread'] = (df['ask_price'] - df['bid_price']) / df['wap']
    df['harmonic_imbalance'] = df.eval('2 / ((1 / bid_size) + (1 / ask_size))')
    
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df['market_urgency'] = df['price_spread'] * df['imb_s1']
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("(ask_price + bid_price) / 2")
    df['mid_price_movement'] = df['mid_price'].diff(periods=5).apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))
    df['mid_price*volume'] = df['mid_price_movement'] * df['volume']
    
    df = calculate_diff_features(df)
    df = calculate_rolling_mean_and_std_expressions(df)
    # df = calculate_gain_loss_features(df)
    df = calculate_norm_features(df)
    df = calculate_bollinger(df)
          
    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance(c, df)
        df[triplet_feature.columns] = triplet_feature.values
        
    df = compute_combination_features(df, prices)
    df = calculate_all_prices_and_sizes_features(df, prices, sizes)
    df = calculate_diff_2_features(df)
    # df = calculate_pct_change_features(df, prices)
            
    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())
        
    df['high_volume'] = np.where(df['bid_plus_ask_sizes'] > df['global_median_vol'], 1, 0) 
    
    # Reduce memory usage
    df = reduce_mem_usage(df)
    
    # Run garbage collector
    gc.collect()
    
    return df.replace([np.inf, -np.inf], 0)

weights = [
    0.004, 0.001, 0.002, 0.006, 0.004, 0.004, 0.002, 0.006, 0.006, 0.002, 0.002, 0.008,
    0.006, 0.002, 0.008, 0.006, 0.002, 0.006, 0.004, 0.002, 0.004, 0.001, 0.006, 0.004,
    0.002, 0.002, 0.004, 0.002, 0.004, 0.004, 0.001, 0.001, 0.002, 0.002, 0.006, 0.004,
    0.004, 0.004, 0.006, 0.002, 0.002, 0.04 , 0.002, 0.002, 0.004, 0.04 , 0.002, 0.001,
    0.006, 0.004, 0.004, 0.006, 0.001, 0.004, 0.004, 0.002, 0.006, 0.004, 0.006, 0.004,
    0.006, 0.004, 0.002, 0.001, 0.002, 0.004, 0.002, 0.008, 0.004, 0.004, 0.002, 0.004,
    0.006, 0.002, 0.004, 0.004, 0.002, 0.004, 0.004, 0.004, 0.001, 0.002, 0.002, 0.008,
    0.02 , 0.004, 0.006, 0.002, 0.02 , 0.002, 0.002, 0.006, 0.004, 0.002, 0.001, 0.02,
    0.006, 0.001, 0.002, 0.004, 0.001, 0.002, 0.006, 0.006, 0.004, 0.006, 0.001, 0.002,
    0.004, 0.006, 0.006, 0.001, 0.04 , 0.006, 0.002, 0.004, 0.002, 0.002, 0.006, 0.002,
    0.002, 0.004, 0.006, 0.006, 0.002, 0.002, 0.008, 0.006, 0.004, 0.002, 0.006, 0.002,
    0.004, 0.006, 0.002, 0.004, 0.001, 0.004, 0.002, 0.004, 0.008, 0.006, 0.008, 0.002,
    0.004, 0.002, 0.001, 0.004, 0.004, 0.004, 0.006, 0.008, 0.004, 0.001, 0.001, 0.002,
    0.006, 0.004, 0.001, 0.002, 0.006, 0.004, 0.006, 0.008, 0.002, 0.002, 0.004, 0.002,
    0.04 , 0.002, 0.002, 0.004, 0.002, 0.002, 0.006, 0.02 , 0.004, 0.002, 0.006, 0.02,
    0.001, 0.002, 0.006, 0.004, 0.006, 0.004, 0.004, 0.004, 0.004, 0.002, 0.004, 0.04,
    0.002, 0.008, 0.002, 0.004, 0.001, 0.004, 0.006, 0.004,
]
weights = {int(k):v for k,v in enumerate(weights)}

# %% [markdown]
# # Dataset

# %%
# Load the dataset
train = pd.read_csv('/kaggle/input/optiver-trading-at-the-close/train.csv')

# Drop nan on target column
train.dropna(subset=['target'], inplace=True)

global_stock_id_feats = {
        "median_vol": train.groupby("stock_id")["bid_size"].median() + train.groupby("stock_id")["ask_size"].median(),
        "std_size": train.groupby("stock_id")["bid_size"].std() + train.groupby("stock_id")["ask_size"].std(),
        "ptp_size": train.groupby("stock_id")["bid_size"].max() - train.groupby("stock_id")["bid_size"].min(),
        "median_price": train.groupby("stock_id")["bid_price"].median() + train.groupby("stock_id")["ask_price"].median(),
        "std_price": train.groupby("stock_id")["bid_price"].std() + train.groupby("stock_id")["ask_price"].std(),
        "ptp_price": train.groupby("stock_id")["bid_price"].max() - train.groupby("stock_id")["ask_price"].min()
}

# Run garbage collector
gc.collect()

# Drop other relevant nan
train.dropna(subset=['bid_price', 'ask_price'], inplace=True)

# Reset the index
train.reset_index(drop=True)

# Apply features engineering
train = feat_eng(train)

# Get X ed Y
y = train['target']
X = train.drop(columns='target')

# Get date ids
date_ids = X['date_id'].values
X = X.drop(columns='date_id')

# Get feature names
feature_name = list(X.columns)

# Run garbage collector
gc.collect()
# Out:
# 0

# %% [markdown]
# # Model

# %%
num_folds = 4
fold_size = 480 // num_folds
gap = 5

stopping_rounds = 100
log_evaluation_periods = 4

# Run garbage collector
gc.collect()


lgb_params = {
    'max_depth': 11,
    'num_leaves': 260,
    #'objective': 'mae', 
    'objective': 'huber', 
    'n_estimators': 7000,
    "colsample_bytree": 0.70,
    'learning_rate': 0.05,
    'reg_lambda': 0.008,
    'reg_alpha': 0.008,
    'importance_type' : 'gain',
    'min_gain_to_split': 0.04,
    'bagging_freq': 4,
    "subsample": 0.70,
    'verbosity': 1,
    'device': 'gpu'
}


# Define lists
models = []

# Loop over data
for i in range(num_folds):
    print(f"\n\nFold {i+1} Model Training")
    start = i * fold_size
    end = start + fold_size
    if i < num_folds - 1:  # No need to purge after the last fold
        purged_start = end - 2
        purged_end = end + gap + 2
        train_indices = (date_ids >= start) & (date_ids < purged_start) | (date_ids > purged_end)
    else:
        train_indices = (date_ids >= start) & (date_ids < end)
    
    val_indices = (date_ids >= end) & (date_ids < end + fold_size)
    
    # Get the data for the current fold
    X_fold_train = X[train_indices]
    y_fold_train = y[train_indices]
    X_fold_valid = X[val_indices]
    y_fold_valid = y[val_indices]
    
    # Define a LightGBM model for the current fold
    lgb_model = lgb.LGBMRegressor(**lgb_params)
    
    # Train the LightGBM model for the current fold
    lgb_model.fit(
        X_fold_train[feature_name],
        y_fold_train,
        eval_set=[(X_fold_valid[feature_name], y_fold_valid)],
        callbacks=[
            lgb.callback.early_stopping(stopping_rounds=stopping_rounds),
            lgb.callback.log_evaluation(period=log_evaluation_periods),
        ],
    )
    
    # Fill the model list
    models.append(lgb_model)
    
    print(f"Model {i+1} best iteration: {lgb_model.best_iteration_}")
    
    # Free up memory by deleting fold specific variables
    del X_fold_train, y_fold_train, X_fold_valid, y_fold_valid
    
    # Run garbage collector
    gc.collect()

print(f"\n\nTrain the last model {i+2} on the entire dataset")
final_model_params = lgb_params

# Train the final model on the entire dataset
final_model = lgb.LGBMRegressor(**final_model_params)
final_model.fit(
    X[feature_name],
    y,
    callbacks=[
            lgb.callback.log_evaluation(period=log_evaluation_periods),
        ],
)

# Append the final model to the list of models
models.append(final_model)

# Run garbage collector
gc.collect()
# Out:
# Fold 1 Model Training
# [LightGBM] [Warning] min_gain_to_split is set=0.04, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.04
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=0.04, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.04
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 34720
# [LightGBM] [Info] Number of data points in the train set: 5129410, number of used features: 172
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 171 dense feature groups (841.39 MB) transferred to GPU in 0.502327 secs. 0 sparse feature groups
# [LightGBM] [Warning] min_gain_to_split is set=0.04, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.04
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Info] Start training from score -0.046080
# Training until validation scores don't improve for 100 rounds
# [4]	valid_0's huber: 6.09047
# [8]	valid_0's huber: 6.08649
# [12]	valid_0's huber: 6.08264
# [16]	valid_0's huber: 6.07891
# [20]	valid_0's huber: 6.07525
# [24]	valid_0's huber: 6.07172
# [28]	valid_0's huber: 6.06826
# [32]	valid_0's huber: 6.06493
# [36]	valid_0's huber: 6.06166
# [40]	valid_0's huber: 6.05846
# [44]	valid_0's huber: 6.05537
# [48]	valid_0's huber: 6.05238
# [52]	valid_0's huber: 6.04941
# [56]	valid_0's huber: 6.04659
# [60]	valid_0's huber: 6.04385
# [64]	valid_0's huber: 6.04115
# [68]	valid_0's huber: 6.03857
# [72]	valid_0's huber: 6.03607
# [76]	valid_0's huber: 6.0336
# [80]	valid_0's huber: 6.03119
# [84]	valid_0's huber: 6.02883
# [88]	valid_0's huber: 6.02657
# [92]	valid_0's huber: 6.02434
# [96]	valid_0's huber: 6.02215
# [100]	valid_0's huber: 6.02005
# [104]	valid_0's huber: 6.018
# [108]	valid_0's huber: 6.01595
# [112]	valid_0's huber: 6.01394
# [116]	valid_0's huber: 6.01203
# [120]	valid_0's huber: 6.01015
# [124]	valid_0's huber: 6.00832
# [128]	valid_0's huber: 6.00659
# [132]	valid_0's huber: 6.00485
# [136]	valid_0's huber: 6.00313
# [140]	valid_0's huber: 6.0015
# [144]	valid_0's huber: 5.9999
# [148]	valid_0's huber: 5.99832
# [152]	valid_0's huber: 5.99679
# [156]	valid_0's huber: 5.99525
# [160]	valid_0's huber: 5.99378
# [164]	valid_0's huber: 5.99232
# [168]	valid_0's huber: 5.99092
# [172]	valid_0's huber: 5.98955
# [176]	valid_0's huber: 5.98821
# [180]	valid_0's huber: 5.9869
# [184]	valid_0's huber: 5.9856
# [188]	valid_0's huber: 5.98435
# [192]	valid_0's huber: 5.98312
# [196]	valid_0's huber: 5.98192
# [200]	valid_0's huber: 5.98075
# [204]	valid_0's huber: 5.97953
# [208]	valid_0's huber: 5.97841
# [212]	valid_0's huber: 5.9773
# [216]	valid_0's huber: 5.97623
# [220]	valid_0's huber: 5.97518
# [224]	valid_0's huber: 5.97417
# [228]	valid_0's huber: 5.97314
# [232]	valid_0's huber: 5.97214
# [236]	valid_0's huber: 5.97118
# [240]	valid_0's huber: 5.97019
# [244]	valid_0's huber: 5.96925
# [248]	valid_0's huber: 5.96833
# [252]	valid_0's huber: 5.96744
# [256]	valid_0's huber: 5.96655
# [260]	valid_0's huber: 5.96566
# [264]	valid_0's huber: 5.96478
# [268]	valid_0's huber: 5.96395
# [272]	valid_0's huber: 5.96309
# [276]	valid_0's huber: 5.9623
# [280]	valid_0's huber: 5.96152
# [284]	valid_0's huber: 5.96076
# [288]	valid_0's huber: 5.95996
# [292]	valid_0's huber: 5.9592
# [296]	valid_0's huber: 5.95843
# [300]	valid_0's huber: 5.95772
# [304]	valid_0's huber: 5.95698
# [308]	valid_0's huber: 5.95629
# [312]	valid_0's huber: 5.95559
# [316]	valid_0's huber: 5.95488
# [320]	valid_0's huber: 5.95418
# [324]	valid_0's huber: 5.95352
# [328]	valid_0's huber: 5.95286
# [332]	valid_0's huber: 5.95224
# [336]	valid_0's huber: 5.95163
# [340]	valid_0's huber: 5.95103
# [344]	valid_0's huber: 5.95042
# [348]	valid_0's huber: 5.94981
# [352]	valid_0's huber: 5.9492
# [356]	valid_0's huber: 5.94861
# [360]	valid_0's huber: 5.94803
# [364]	valid_0's huber: 5.94745
# [368]	valid_0's huber: 5.94688
# [372]	valid_0's huber: 5.94634
# [376]	valid_0's huber: 5.94575
# [380]	valid_0's huber: 5.94521
# [384]	valid_0's huber: 5.94466
# [388]	valid_0's huber: 5.94413
# [392]	valid_0's huber: 5.94362
# [396]	valid_0's huber: 5.94314
# [400]	valid_0's huber: 5.94262
# [404]	valid_0's huber: 5.94214
# [408]	valid_0's huber: 5.94165
# [412]	valid_0's huber: 5.9412
# [416]	valid_0's huber: 5.94067
# [420]	valid_0's huber: 5.94019
# [424]	valid_0's huber: 5.93966
# [428]	valid_0's huber: 5.93917
# [432]	valid_0's huber: 5.93869
# [436]	valid_0's huber: 5.93822
# [440]	valid_0's huber: 5.93776
# [444]	valid_0's huber: 5.9373
# [448]	valid_0's huber: 5.93683
# [452]	valid_0's huber: 5.9364
# [456]	valid_0's huber: 5.93596
# [460]	valid_0's huber: 5.93552
# [464]	valid_0's huber: 5.9351
# [468]	valid_0's huber: 5.93468
# [472]	valid_0's huber: 5.93425
# [476]	valid_0's huber: 5.93379
# [480]	valid_0's huber: 5.93334
# [484]	valid_0's huber: 5.93296
# [488]	valid_0's huber: 5.93254
# [492]	valid_0's huber: 5.93211
# [496]	valid_0's huber: 5.93169
# [500]	valid_0's huber: 5.93126
# [504]	valid_0's huber: 5.93084
# [508]	valid_0's huber: 5.9304
# [512]	valid_0's huber: 5.93003
# [516]	valid_0's huber: 5.92963
# [520]	valid_0's huber: 5.92924
# [524]	valid_0's huber: 5.92887
# [528]	valid_0's huber: 5.92851
# [532]	valid_0's huber: 5.92811
# [536]	valid_0's huber: 5.92768
# [540]	valid_0's huber: 5.92728
# [544]	valid_0's huber: 5.9269
# [548]	valid_0's huber: 5.92653
# [552]	valid_0's huber: 5.92617
# [556]	valid_0's huber: 5.92576
# [560]	valid_0's huber: 5.92536
# [564]	valid_0's huber: 5.92499
# [568]	valid_0's huber: 5.92462
# [572]	valid_0's huber: 5.92429
# [576]	valid_0's huber: 5.92395
# [580]	valid_0's huber: 5.92358
# [584]	valid_0's huber: 5.92323
# [588]	valid_0's huber: 5.92288
# [592]	valid_0's huber: 5.92255
# [596]	valid_0's huber: 5.9222
# [600]	valid_0's huber: 5.92186
# [604]	valid_0's huber: 5.92154
# [608]	valid_0's huber: 5.92121
# [612]	valid_0's huber: 5.92087
# [616]	valid_0's huber: 5.92055
# [620]	valid_0's huber: 5.9202
# [624]	valid_0's huber: 5.91986
# [628]	valid_0's huber: 5.91954
# [632]	valid_0's huber: 5.91925
# [636]	valid_0's huber: 5.9189
# [640]	valid_0's huber: 5.91857
# [644]	valid_0's huber: 5.91825
# [648]	valid_0's huber: 5.91793
# [652]	valid_0's huber: 5.91761
# [656]	valid_0's huber: 5.91731
# [660]	valid_0's huber: 5.91703
# [664]	valid_0's huber: 5.91673
# [668]	valid_0's huber: 5.91645
# [672]	valid_0's huber: 5.91616
# [676]	valid_0's huber: 5.91585
# [680]	valid_0's huber: 5.91556
# [684]	valid_0's huber: 5.91528
# [688]	valid_0's huber: 5.91499
# [692]	valid_0's huber: 5.91465
# [696]	valid_0's huber: 5.91434
# [700]	valid_0's huber: 5.91401
# [704]	valid_0's huber: 5.91371
# [708]	valid_0's huber: 5.91338
# [712]	valid_0's huber: 5.91309
# [716]	valid_0's huber: 5.9128
# [720]	valid_0's huber: 5.91251
# [724]	valid_0's huber: 5.91225
# [728]	valid_0's huber: 5.91194
# [732]	valid_0's huber: 5.91163
# [736]	valid_0's huber: 5.91132
# [740]	valid_0's huber: 5.91105
# [744]	valid_0's huber: 5.9108
# [748]	valid_0's huber: 5.91052
# [752]	valid_0's huber: 5.9102
# [756]	valid_0's huber: 5.90991
# [760]	valid_0's huber: 5.90962
# [764]	valid_0's huber: 5.90935
# [768]	valid_0's huber: 5.90909
# [772]	valid_0's huber: 5.90884
# [776]	valid_0's huber: 5.90854
# [780]	valid_0's huber: 5.90827
# [784]	valid_0's huber: 5.90799
# [788]	valid_0's huber: 5.9077
# [792]	valid_0's huber: 5.90745
# [796]	valid_0's huber: 5.9072
# [800]	valid_0's huber: 5.90692
# [804]	valid_0's huber: 5.90666
# [808]	valid_0's huber: 5.90642
# [812]	valid_0's huber: 5.90619
# [816]	valid_0's huber: 5.90592
# [820]	valid_0's huber: 5.90563
# [824]	valid_0's huber: 5.90537
# [828]	valid_0's huber: 5.90511
# [832]	valid_0's huber: 5.90485
# [836]	valid_0's huber: 5.90459
# [840]	valid_0's huber: 5.90427
# [844]	valid_0's huber: 5.90404
# [848]	valid_0's huber: 5.90379
# [852]	valid_0's huber: 5.9035
# [856]	valid_0's huber: 5.90324
# [860]	valid_0's huber: 5.90302
# [864]	valid_0's huber: 5.90277
# [868]	valid_0's huber: 5.90251
# [872]	valid_0's huber: 5.90228
# [876]	valid_0's huber: 5.90207
# [880]	valid_0's huber: 5.90183
# [884]	valid_0's huber: 5.90158
# [888]	valid_0's huber: 5.90135
# [892]	valid_0's huber: 5.90106
# [896]	valid_0's huber: 5.90081
# [900]	valid_0's huber: 5.90058
# [904]	valid_0's huber: 5.90034
# [908]	valid_0's huber: 5.90011
# [912]	valid_0's huber: 5.89986
# [916]	valid_0's huber: 5.89958
# [920]	valid_0's huber: 5.89937
# [924]	valid_0's huber: 5.89914
# [928]	valid_0's huber: 5.89889
# [932]	valid_0's huber: 5.89867
# [936]	valid_0's huber: 5.89842
# [940]	valid_0's huber: 5.89815
# [944]	valid_0's huber: 5.89792
# [948]	valid_0's huber: 5.89771
# [952]	valid_0's huber: 5.89749
# [956]	valid_0's huber: 5.89723
# [960]	valid_0's huber: 5.89698
# [964]	valid_0's huber: 5.89676
# [968]	valid_0's huber: 5.89648
# [972]	valid_0's huber: 5.89624
# [976]	valid_0's huber: 5.89602
# [980]	valid_0's huber: 5.89576
# [984]	valid_0's huber: 5.89553
# [988]	valid_0's huber: 5.8953
# [992]	valid_0's huber: 5.89508
# [996]	valid_0's huber: 5.89484
# [1000]	valid_0's huber: 5.89459
# [1004]	valid_0's huber: 5.89438
# [1008]	valid_0's huber: 5.89412
# [1012]	valid_0's huber: 5.89388
# [1016]	valid_0's huber: 5.89361
# [1020]	valid_0's huber: 5.89335
# [1024]	valid_0's huber: 5.89311
# [1028]	valid_0's huber: 5.89285
# [1032]	valid_0's huber: 5.89263
# [1036]	valid_0's huber: 5.89236
# [1040]	valid_0's huber: 5.89213
# [1044]	valid_0's huber: 5.89188
# [1048]	valid_0's huber: 5.89164
# [1052]	valid_0's huber: 5.8914
# [1056]	valid_0's huber: 5.8912
# [1060]	valid_0's huber: 5.89101
# [1064]	valid_0's huber: 5.8908
# [1068]	valid_0's huber: 5.89061
# [1072]	valid_0's huber: 5.89037
# [1076]	valid_0's huber: 5.89016
# [1080]	valid_0's huber: 5.88997
# [1084]	valid_0's huber: 5.88974
# [1088]	valid_0's huber: 5.8895
# [1092]	valid_0's huber: 5.88931
# [1096]	valid_0's huber: 5.88907
# [1100]	valid_0's huber: 5.88887
# [1104]	valid_0's huber: 5.88863
# [1108]	valid_0's huber: 5.88841
# [1112]	valid_0's huber: 5.88817
# [1116]	valid_0's huber: 5.88797
# [1120]	valid_0's huber: 5.88779
# [1124]	valid_0's huber: 5.88759
# [1128]	valid_0's huber: 5.88738
# [1132]	valid_0's huber: 5.88719
# [1136]	valid_0's huber: 5.88697
# [1140]	valid_0's huber: 5.88674
# [1144]	valid_0's huber: 5.8865
# [1148]	valid_0's huber: 5.88629
# [1152]	valid_0's huber: 5.88608
# [1156]	valid_0's huber: 5.88586
# [1160]	valid_0's huber: 5.88564
# [1164]	valid_0's huber: 5.88546
# [1168]	valid_0's huber: 5.88522
# [1172]	valid_0's huber: 5.88499
# [1176]	valid_0's huber: 5.88475
# [1180]	valid_0's huber: 5.88452
# [1184]	valid_0's huber: 5.88428
# [1188]	valid_0's huber: 5.88405
# [1192]	valid_0's huber: 5.88384
# [1196]	valid_0's huber: 5.88363
# [1200]	valid_0's huber: 5.88342
# [1204]	valid_0's huber: 5.88321
# [1208]	valid_0's huber: 5.88299
# [1212]	valid_0's huber: 5.88279
# [1216]	valid_0's huber: 5.88257
# [1220]	valid_0's huber: 5.88232
# [1224]	valid_0's huber: 5.88213
# [1228]	valid_0's huber: 5.88196
# [1232]	valid_0's huber: 5.88171
# [1236]	valid_0's huber: 5.88152
# [1240]	valid_0's huber: 5.88127
# [1244]	valid_0's huber: 5.88107
# [1248]	valid_0's huber: 5.88083
# [1252]	valid_0's huber: 5.88061
# [1256]	valid_0's huber: 5.8804
# [1260]	valid_0's huber: 5.88018
# [1264]	valid_0's huber: 5.87999
# [1268]	valid_0's huber: 5.87979
# [1272]	valid_0's huber: 5.87957
# [1276]	valid_0's huber: 5.87937
# [1280]	valid_0's huber: 5.87912
# [1284]	valid_0's huber: 5.87889
# [1288]	valid_0's huber: 5.87865
# [1292]	valid_0's huber: 5.87844
# [1296]	valid_0's huber: 5.87822
# [1300]	valid_0's huber: 5.87803
# [1304]	valid_0's huber: 5.87777
# [1308]	valid_0's huber: 5.87759
# [1312]	valid_0's huber: 5.8774
# [1316]	valid_0's huber: 5.87717
# [1320]	valid_0's huber: 5.87694
# [1324]	valid_0's huber: 5.87672
# [1328]	valid_0's huber: 5.87655
# [1332]	valid_0's huber: 5.87636
# [1336]	valid_0's huber: 5.87618
# [1340]	valid_0's huber: 5.87595
# [1344]	valid_0's huber: 5.87574
# [1348]	valid_0's huber: 5.87554
# [1352]	valid_0's huber: 5.87538
# [1356]	valid_0's huber: 5.87515
# [1360]	valid_0's huber: 5.87494
# [1364]	valid_0's huber: 5.87471
# [1368]	valid_0's huber: 5.87452
# [1372]	valid_0's huber: 5.87436
# [1376]	valid_0's huber: 5.8742
# [1380]	valid_0's huber: 5.87399
# [1384]	valid_0's huber: 5.87379
# [1388]	valid_0's huber: 5.87356
# [1392]	valid_0's huber: 5.8734
# [1396]	valid_0's huber: 5.87316
# [1400]	valid_0's huber: 5.87295
# [1404]	valid_0's huber: 5.87273
# [1408]	valid_0's huber: 5.87251
# [1412]	valid_0's huber: 5.87232
# [1416]	valid_0's huber: 5.87213
# [1420]	valid_0's huber: 5.8719
# [1424]	valid_0's huber: 5.87169
# [1428]	valid_0's huber: 5.87148
# [1432]	valid_0's huber: 5.87127
# [1436]	valid_0's huber: 5.87104
# [1440]	valid_0's huber: 5.87082
# [1444]	valid_0's huber: 5.87063
# [1448]	valid_0's huber: 5.87045
# [1452]	valid_0's huber: 5.87029
# [1456]	valid_0's huber: 5.87008
# [1460]	valid_0's huber: 5.86991
# [1464]	valid_0's huber: 5.86971
# [1468]	valid_0's huber: 5.86946
# [1472]	valid_0's huber: 5.86923
# [1476]	valid_0's huber: 5.86902
# [1480]	valid_0's huber: 5.86886
# [1484]	valid_0's huber: 5.86869
# [1488]	valid_0's huber: 5.86851
# [1492]	valid_0's huber: 5.86827
# [1496]	valid_0's huber: 5.86806
# [1500]	valid_0's huber: 5.86786
# [1504]	valid_0's huber: 5.86767
# [1508]	valid_0's huber: 5.86748
# [1512]	valid_0's huber: 5.86724
# [1516]	valid_0's huber: 5.86707
# [1520]	valid_0's huber: 5.86689
# [1524]	valid_0's huber: 5.8667
# [1528]	valid_0's huber: 5.8665
# [1532]	valid_0's huber: 5.86633
# [1536]	valid_0's huber: 5.86613
# [1540]	valid_0's huber: 5.866
# [1544]	valid_0's huber: 5.86581
# [1548]	valid_0's huber: 5.86564
# [1552]	valid_0's huber: 5.86548
# [1556]	valid_0's huber: 5.86532
# [1560]	valid_0's huber: 5.86514
# [1564]	valid_0's huber: 5.86494
# [1568]	valid_0's huber: 5.86473
# [1572]	valid_0's huber: 5.86456
# [1576]	valid_0's huber: 5.86437
# [1580]	valid_0's huber: 5.86412
# [1584]	valid_0's huber: 5.86389
# [1588]	valid_0's huber: 5.8637
# [1592]	valid_0's huber: 5.86353
# [1596]	valid_0's huber: 5.86335
# [1600]	valid_0's huber: 5.86317
# [1604]	valid_0's huber: 5.86302
# [1608]	valid_0's huber: 5.86284
# [1612]	valid_0's huber: 5.86264
# [1616]	valid_0's huber: 5.86239
# [1620]	valid_0's huber: 5.86222
# [1624]	valid_0's huber: 5.86199
# [1628]	valid_0's huber: 5.86179
# [1632]	valid_0's huber: 5.86162
# [1636]	valid_0's huber: 5.86143
# [1640]	valid_0's huber: 5.86122
# [1644]	valid_0's huber: 5.86103
# [1648]	valid_0's huber: 5.86084
# [1652]	valid_0's huber: 5.86066
# [1656]	valid_0's huber: 5.86047
# [1660]	valid_0's huber: 5.86028
# [1664]	valid_0's huber: 5.86014
# [1668]	valid_0's huber: 5.85994
# [1672]	valid_0's huber: 5.85975
# [1676]	valid_0's huber: 5.8595
# [1680]	valid_0's huber: 5.85931
# [1684]	valid_0's huber: 5.85913
# [1688]	valid_0's huber: 5.85891
# [1692]	valid_0's huber: 5.85871
# [1696]	valid_0's huber: 5.85854
# [1700]	valid_0's huber: 5.85839
# [1704]	valid_0's huber: 5.85817
# [1708]	valid_0's huber: 5.85795
# [1712]	valid_0's huber: 5.85779
# [1716]	valid_0's huber: 5.85763
# [1720]	valid_0's huber: 5.85751
# [1724]	valid_0's huber: 5.85735
# [1728]	valid_0's huber: 5.85715
# [1732]	valid_0's huber: 5.85699
# [1736]	valid_0's huber: 5.85682
# [1740]	valid_0's huber: 5.85667
# [1744]	valid_0's huber: 5.8565
# [1748]	valid_0's huber: 5.85633
# [1752]	valid_0's huber: 5.85617
# [1756]	valid_0's huber: 5.85599
# [1760]	valid_0's huber: 5.8558
# [1764]	valid_0's huber: 5.85565
# [1768]	valid_0's huber: 5.85543
# [1772]	valid_0's huber: 5.85527
# [1776]	valid_0's huber: 5.85509
# [1780]	valid_0's huber: 5.85495
# [1784]	valid_0's huber: 5.85477
# [1788]	valid_0's huber: 5.85459
# [1792]	valid_0's huber: 5.85443
# [1796]	valid_0's huber: 5.85422
# [1800]	valid_0's huber: 5.85406
# [1804]	valid_0's huber: 5.85387
# [1808]	valid_0's huber: 5.85371
# [1812]	valid_0's huber: 5.85355
# [1816]	valid_0's huber: 5.85337
# [1820]	valid_0's huber: 5.85323
# [1824]	valid_0's huber: 5.85305
# [1828]	valid_0's huber: 5.85289
# [1832]	valid_0's huber: 5.85272
# [1836]	valid_0's huber: 5.85257
# [1840]	valid_0's huber: 5.85244
# [1844]	valid_0's huber: 5.85227
# [1848]	valid_0's huber: 5.85211
# [1852]	valid_0's huber: 5.85196
# [1856]	valid_0's huber: 5.8518
# [1860]	valid_0's huber: 5.85163
# [1864]	valid_0's huber: 5.85152
# [1868]	valid_0's huber: 5.85135
# [1872]	valid_0's huber: 5.85119
# [1876]	valid_0's huber: 5.85103
# [1880]	valid_0's huber: 5.85087
# [1884]	valid_0's huber: 5.85072
# [1888]	valid_0's huber: 5.85056
# [1892]	valid_0's huber: 5.85041
# [1896]	valid_0's huber: 5.85024
# [1900]	valid_0's huber: 5.85009
# [1904]	valid_0's huber: 5.84994
# [1908]	valid_0's huber: 5.84967
# [1912]	valid_0's huber: 5.84948
# [1916]	valid_0's huber: 5.84932
# [1920]	valid_0's huber: 5.84912
# [1924]	valid_0's huber: 5.84897
# [1928]	valid_0's huber: 5.84879
# [1932]	valid_0's huber: 5.84866
# [1936]	valid_0's huber: 5.84848
# [1940]	valid_0's huber: 5.84828
# [1944]	valid_0's huber: 5.84806
# [1948]	valid_0's huber: 5.84789
# [1952]	valid_0's huber: 5.84772
# [1956]	valid_0's huber: 5.84755
# [1960]	valid_0's huber: 5.84739
# [1964]	valid_0's huber: 5.84717
# [1968]	valid_0's huber: 5.84698
# [1972]	valid_0's huber: 5.84683
# [1976]	valid_0's huber: 5.84665
# [1980]	valid_0's huber: 5.84647
# [1984]	valid_0's huber: 5.84634
# [1988]	valid_0's huber: 5.84616
# [1992]	valid_0's huber: 5.846
# [1996]	valid_0's huber: 5.8458
# [2000]	valid_0's huber: 5.84565
# [2004]	valid_0's huber: 5.84549
# [2008]	valid_0's huber: 5.84538
# [2012]	valid_0's huber: 5.8452
# [2016]	valid_0's huber: 5.84506
# [2020]	valid_0's huber: 5.84489
# [2024]	valid_0's huber: 5.84472
# [2028]	valid_0's huber: 5.84457
# [2032]	valid_0's huber: 5.84435
# [2036]	valid_0's huber: 5.8442
# [2040]	valid_0's huber: 5.84406
# [2044]	valid_0's huber: 5.84392
# [2048]	valid_0's huber: 5.84378
# [2052]	valid_0's huber: 5.84359
# [2056]	valid_0's huber: 5.84344
# [2060]	valid_0's huber: 5.84328
# [2064]	valid_0's huber: 5.84311
# [2068]	valid_0's huber: 5.84295
# [2072]	valid_0's huber: 5.8428
# [2076]	valid_0's huber: 5.84265
# [2080]	valid_0's huber: 5.84251
# [2084]	valid_0's huber: 5.84234
# [2088]	valid_0's huber: 5.84216
# [2092]	valid_0's huber: 5.84198
# [2096]	valid_0's huber: 5.84184
# [2100]	valid_0's huber: 5.8417
# [2104]	valid_0's huber: 5.84154
# [2108]	valid_0's huber: 5.84136
# [2112]	valid_0's huber: 5.84119
# [2116]	valid_0's huber: 5.84107
# [2120]	valid_0's huber: 5.84094
# [2124]	valid_0's huber: 5.8408
# [2128]	valid_0's huber: 5.84052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2132]	valid_0's huber: 5.84038
# [2136]	valid_0's huber: 5.84025
# [2140]	valid_0's huber: 5.84008
# [2144]	valid_0's huber: 5.83991
# [2148]	valid_0's huber: 5.83976
# [2152]	valid_0's huber: 5.8396
# [2156]	valid_0's huber: 5.83943
# [2160]	valid_0's huber: 5.83926
# [2164]	valid_0's huber: 5.83907
# [2168]	valid_0's huber: 5.83891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2172]	valid_0's huber: 5.83877
# [2176]	valid_0's huber: 5.83861
# [2180]	valid_0's huber: 5.8384
# [2184]	valid_0's huber: 5.83824
# [2188]	valid_0's huber: 5.83805
# [2192]	valid_0's huber: 5.83791
# [2196]	valid_0's huber: 5.83773
# [2200]	valid_0's huber: 5.83758
# [2204]	valid_0's huber: 5.83743
# [2208]	valid_0's huber: 5.83729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2212]	valid_0's huber: 5.8372
# [2216]	valid_0's huber: 5.83703
# [2220]	valid_0's huber: 5.8369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2224]	valid_0's huber: 5.83684
# [2228]	valid_0's huber: 5.83669
# [2232]	valid_0's huber: 5.83657
# [2236]	valid_0's huber: 5.83643
# [2240]	valid_0's huber: 5.83628
# [2244]	valid_0's huber: 5.83613
# [2248]	valid_0's huber: 5.83596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2252]	valid_0's huber: 5.83582
# [2256]	valid_0's huber: 5.83567
# [2260]	valid_0's huber: 5.83558
# [2264]	valid_0's huber: 5.83543
# [2268]	valid_0's huber: 5.83528
# [2272]	valid_0's huber: 5.83516
# [2276]	valid_0's huber: 5.83502
# [2280]	valid_0's huber: 5.83487
# [2284]	valid_0's huber: 5.8347
# [2288]	valid_0's huber: 5.83457
# [2292]	valid_0's huber: 5.83438
# [2296]	valid_0's huber: 5.83423
# [2300]	valid_0's huber: 5.83408
# [2304]	valid_0's huber: 5.83393
# [2308]	valid_0's huber: 5.83378
# [2312]	valid_0's huber: 5.83364
# [2316]	valid_0's huber: 5.83351
# [2320]	valid_0's huber: 5.83333
# [2324]	valid_0's huber: 5.8332
# [2328]	valid_0's huber: 5.83303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2332]	valid_0's huber: 5.83289
# [2336]	valid_0's huber: 5.83272
# [2340]	valid_0's huber: 5.83254
# [2344]	valid_0's huber: 5.83236
# [2348]	valid_0's huber: 5.83224
# [2352]	valid_0's huber: 5.83209
# [2356]	valid_0's huber: 5.83191
# [2360]	valid_0's huber: 5.83183
# [2364]	valid_0's huber: 5.83164
# [2368]	valid_0's huber: 5.8315
# [2372]	valid_0's huber: 5.83134
# [2376]	valid_0's huber: 5.83124
# [2380]	valid_0's huber: 5.83106
# [2384]	valid_0's huber: 5.83092
# [2388]	valid_0's huber: 5.83077
# [2392]	valid_0's huber: 5.83062
# [2396]	valid_0's huber: 5.83049
# [2400]	valid_0's huber: 5.83034
# [2404]	valid_0's huber: 5.83021
# [2408]	valid_0's huber: 5.83006
# [2412]	valid_0's huber: 5.82994
# [2416]	valid_0's huber: 5.82977
# [2420]	valid_0's huber: 5.82965
# [2424]	valid_0's huber: 5.8295
# [2428]	valid_0's huber: 5.82933
# [2432]	valid_0's huber: 5.82917
# [2436]	valid_0's huber: 5.82903
# [2440]	valid_0's huber: 5.82884
# [2444]	valid_0's huber: 5.82864
# [2448]	valid_0's huber: 5.82847
# [2452]	valid_0's huber: 5.82833
# [2456]	valid_0's huber: 5.8282
# [2460]	valid_0's huber: 5.82805
# [2464]	valid_0's huber: 5.82787
# [2468]	valid_0's huber: 5.82774
# [2472]	valid_0's huber: 5.82764
# [2476]	valid_0's huber: 5.82748
# [2480]	valid_0's huber: 5.82734
# [2484]	valid_0's huber: 5.8272
# [2488]	valid_0's huber: 5.82701
# [2492]	valid_0's huber: 5.82683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2496]	valid_0's huber: 5.82671
# [2500]	valid_0's huber: 5.82655
# [2504]	valid_0's huber: 5.82641
# [2508]	valid_0's huber: 5.82626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2512]	valid_0's huber: 5.82616
# [2516]	valid_0's huber: 5.82602
# [2520]	valid_0's huber: 5.82589
# [2524]	valid_0's huber: 5.82575
# [2528]	valid_0's huber: 5.82562
# [2532]	valid_0's huber: 5.82547
# [2536]	valid_0's huber: 5.82534
# [2540]	valid_0's huber: 5.82521
# [2544]	valid_0's huber: 5.82509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2548]	valid_0's huber: 5.82499
# [2552]	valid_0's huber: 5.82485
# [2556]	valid_0's huber: 5.82472
# [2560]	valid_0's huber: 5.82458
# [2564]	valid_0's huber: 5.82444
# [2568]	valid_0's huber: 5.82431
# [2572]	valid_0's huber: 5.82421
# [2576]	valid_0's huber: 5.82406
# [2580]	valid_0's huber: 5.82389
# [2584]	valid_0's huber: 5.82373
# [2588]	valid_0's huber: 5.82357
# [2592]	valid_0's huber: 5.82347
# [2596]	valid_0's huber: 5.82332
# [2600]	valid_0's huber: 5.8232
# [2604]	valid_0's huber: 5.8231
# [2608]	valid_0's huber: 5.82296
# [2612]	valid_0's huber: 5.82279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2616]	valid_0's huber: 5.82269
# [2620]	valid_0's huber: 5.82255
# [2624]	valid_0's huber: 5.82241
# [2628]	valid_0's huber: 5.82227
# [2632]	valid_0's huber: 5.82212
# [2636]	valid_0's huber: 5.82197
# [2640]	valid_0's huber: 5.82181
# [2644]	valid_0's huber: 5.82165
# [2648]	valid_0's huber: 5.82149
# [2652]	valid_0's huber: 5.82133
# [2656]	valid_0's huber: 5.8212
# [2660]	valid_0's huber: 5.82103
# [2664]	valid_0's huber: 5.82087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2668]	valid_0's huber: 5.82077
# [2672]	valid_0's huber: 5.82061
# [2676]	valid_0's huber: 5.82047
# [2680]	valid_0's huber: 5.82033
# [2684]	valid_0's huber: 5.82022
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2688]	valid_0's huber: 5.82009
# [2692]	valid_0's huber: 5.81998
# [2696]	valid_0's huber: 5.81982
# [2700]	valid_0's huber: 5.81968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2704]	valid_0's huber: 5.81958
# [2708]	valid_0's huber: 5.81944
# [2712]	valid_0's huber: 5.81931
# [2716]	valid_0's huber: 5.81919
# [2720]	valid_0's huber: 5.81901
# [2724]	valid_0's huber: 5.81885
# [2728]	valid_0's huber: 5.81873
# [2732]	valid_0's huber: 5.81861
# [2736]	valid_0's huber: 5.81846
# [2740]	valid_0's huber: 5.81832
# [2744]	valid_0's huber: 5.81819
# [2748]	valid_0's huber: 5.81806
# [2752]	valid_0's huber: 5.81792
# [2756]	valid_0's huber: 5.8178
# [2760]	valid_0's huber: 5.81765
# [2764]	valid_0's huber: 5.81752
# [2768]	valid_0's huber: 5.81737
# [2772]	valid_0's huber: 5.81718
# [2776]	valid_0's huber: 5.81705
# [2780]	valid_0's huber: 5.81691
# [2784]	valid_0's huber: 5.81673
# [2788]	valid_0's huber: 5.81663
# [2792]	valid_0's huber: 5.81647
# [2796]	valid_0's huber: 5.81629
# [2800]	valid_0's huber: 5.81614
# [2804]	valid_0's huber: 5.816
# [2808]	valid_0's huber: 5.81587
# [2812]	valid_0's huber: 5.81574
# [2816]	valid_0's huber: 5.81559
# [2820]	valid_0's huber: 5.81546
# [2824]	valid_0's huber: 5.81535
# [2828]	valid_0's huber: 5.81522
# [2832]	valid_0's huber: 5.81508
# [2836]	valid_0's huber: 5.81495
# [2840]	valid_0's huber: 5.81481
# [2844]	valid_0's huber: 5.81466
# [2848]	valid_0's huber: 5.81451
# [2852]	valid_0's huber: 5.81436
# [2856]	valid_0's huber: 5.81425
# [2860]	valid_0's huber: 5.81414
# [2864]	valid_0's huber: 5.81402
# [2868]	valid_0's huber: 5.8139
# [2872]	valid_0's huber: 5.81378
# [2876]	valid_0's huber: 5.81367
# [2880]	valid_0's huber: 5.81354
# [2884]	valid_0's huber: 5.81338
# [2888]	valid_0's huber: 5.81321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2892]	valid_0's huber: 5.81308
# [2896]	valid_0's huber: 5.81295
# [2900]	valid_0's huber: 5.81284
# [2904]	valid_0's huber: 5.81271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2908]	valid_0's huber: 5.8126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2912]	valid_0's huber: 5.8125
# [2916]	valid_0's huber: 5.81237
# [2920]	valid_0's huber: 5.81225
# [2924]	valid_0's huber: 5.81213
# [2928]	valid_0's huber: 5.81199
# [2932]	valid_0's huber: 5.81187
# [2936]	valid_0's huber: 5.81171
# [2940]	valid_0's huber: 5.81158
# [2944]	valid_0's huber: 5.81144
# [2948]	valid_0's huber: 5.81128
# [2952]	valid_0's huber: 5.81115
# [2956]	valid_0's huber: 5.81101
# [2960]	valid_0's huber: 5.81086
# [2964]	valid_0's huber: 5.81071
# [2968]	valid_0's huber: 5.8106
# [2972]	valid_0's huber: 5.81047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2976]	valid_0's huber: 5.81035
# [2980]	valid_0's huber: 5.81019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2984]	valid_0's huber: 5.81006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2988]	valid_0's huber: 5.80993
# [2992]	valid_0's huber: 5.80981
# [2996]	valid_0's huber: 5.80964
# [3000]	valid_0's huber: 5.80953
# [3004]	valid_0's huber: 5.80938
# [3008]	valid_0's huber: 5.80924
# [3012]	valid_0's huber: 5.80905
# [3016]	valid_0's huber: 5.80893
# [3020]	valid_0's huber: 5.80879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3024]	valid_0's huber: 5.8087
# [3028]	valid_0's huber: 5.80859
# [3032]	valid_0's huber: 5.80846
# [3036]	valid_0's huber: 5.8083
# [3040]	valid_0's huber: 5.8082
# [3044]	valid_0's huber: 5.80803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3048]	valid_0's huber: 5.80793
# [3052]	valid_0's huber: 5.8078
# [3056]	valid_0's huber: 5.8077
# [3060]	valid_0's huber: 5.80755
# [3064]	valid_0's huber: 5.80738
# [3068]	valid_0's huber: 5.80723
# [3072]	valid_0's huber: 5.80706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3076]	valid_0's huber: 5.80693
# [3080]	valid_0's huber: 5.80679
# [3084]	valid_0's huber: 5.80671
# [3088]	valid_0's huber: 5.80659
# [3092]	valid_0's huber: 5.80645
# [3096]	valid_0's huber: 5.80631
# [3100]	valid_0's huber: 5.80619
# [3104]	valid_0's huber: 5.80605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3108]	valid_0's huber: 5.80594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3112]	valid_0's huber: 5.80589
# [3116]	valid_0's huber: 5.80574
# [3120]	valid_0's huber: 5.8056
# [3124]	valid_0's huber: 5.80549
# [3128]	valid_0's huber: 5.80537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3132]	valid_0's huber: 5.80531
# [3136]	valid_0's huber: 5.80519
# [3140]	valid_0's huber: 5.80507
# [3144]	valid_0's huber: 5.8049
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3148]	valid_0's huber: 5.80478
# [3152]	valid_0's huber: 5.80466
# [3156]	valid_0's huber: 5.80454
# [3160]	valid_0's huber: 5.80441
# [3164]	valid_0's huber: 5.80428
# [3168]	valid_0's huber: 5.80413
# [3172]	valid_0's huber: 5.804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3176]	valid_0's huber: 5.80388
# [3180]	valid_0's huber: 5.80379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3184]	valid_0's huber: 5.80366
# [3188]	valid_0's huber: 5.80352
# [3192]	valid_0's huber: 5.80336
# [3196]	valid_0's huber: 5.80315
# [3200]	valid_0's huber: 5.80301
# [3204]	valid_0's huber: 5.8029
# [3208]	valid_0's huber: 5.80277
# [3212]	valid_0's huber: 5.80266
# [3216]	valid_0's huber: 5.80249
# [3220]	valid_0's huber: 5.80234
# [3224]	valid_0's huber: 5.80221
# [3228]	valid_0's huber: 5.80211
# [3232]	valid_0's huber: 5.80198
# [3236]	valid_0's huber: 5.80187
# [3240]	valid_0's huber: 5.80174
# [3244]	valid_0's huber: 5.8016
# [3248]	valid_0's huber: 5.80146
# [3252]	valid_0's huber: 5.80136
# [3256]	valid_0's huber: 5.80121
# [3260]	valid_0's huber: 5.8011
# [3264]	valid_0's huber: 5.80097
# [3268]	valid_0's huber: 5.80083
# [3272]	valid_0's huber: 5.80066
# [3276]	valid_0's huber: 5.80053
# [3280]	valid_0's huber: 5.80039
# [3284]	valid_0's huber: 5.80026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3288]	valid_0's huber: 5.80013
# [3292]	valid_0's huber: 5.79998
# [3296]	valid_0's huber: 5.79984
# [3300]	valid_0's huber: 5.79971
# [3304]	valid_0's huber: 5.79956
# [3308]	valid_0's huber: 5.79938
# [3312]	valid_0's huber: 5.79927
# [3316]	valid_0's huber: 5.79912
# [3320]	valid_0's huber: 5.79898
# [3324]	valid_0's huber: 5.79887
# [3328]	valid_0's huber: 5.79875
# [3332]	valid_0's huber: 5.79861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3336]	valid_0's huber: 5.7985
# [3340]	valid_0's huber: 5.79836
# [3344]	valid_0's huber: 5.79822
# [3348]	valid_0's huber: 5.79808
# [3352]	valid_0's huber: 5.79789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3356]	valid_0's huber: 5.79778
# [3360]	valid_0's huber: 5.79764
# [3364]	valid_0's huber: 5.79748
# [3368]	valid_0's huber: 5.79734
# [3372]	valid_0's huber: 5.79723
# [3376]	valid_0's huber: 5.79711
# [3380]	valid_0's huber: 5.79699
# [3384]	valid_0's huber: 5.79684
# [3388]	valid_0's huber: 5.79671
# [3392]	valid_0's huber: 5.79657
# [3396]	valid_0's huber: 5.79641
# [3400]	valid_0's huber: 5.79626
# [3404]	valid_0's huber: 5.79615
# [3408]	valid_0's huber: 5.79603
# [3412]	valid_0's huber: 5.79589
# [3416]	valid_0's huber: 5.79577
# [3420]	valid_0's huber: 5.79562
# [3424]	valid_0's huber: 5.79546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3428]	valid_0's huber: 5.79536
# [3432]	valid_0's huber: 5.79519
# [3436]	valid_0's huber: 5.79505
# [3440]	valid_0's huber: 5.79492
# [3444]	valid_0's huber: 5.79479
# [3448]	valid_0's huber: 5.79464
# [3452]	valid_0's huber: 5.79448
# [3456]	valid_0's huber: 5.79437
# [3460]	valid_0's huber: 5.79426
# [3464]	valid_0's huber: 5.79416
# [3468]	valid_0's huber: 5.79402
# [3472]	valid_0's huber: 5.79389
# [3476]	valid_0's huber: 5.79375
# [3480]	valid_0's huber: 5.79365
# [3484]	valid_0's huber: 5.79354
# [3488]	valid_0's huber: 5.79341
# [3492]	valid_0's huber: 5.79328
# [3496]	valid_0's huber: 5.79318
# [3500]	valid_0's huber: 5.79305
# [3504]	valid_0's huber: 5.7929
# [3508]	valid_0's huber: 5.79278
# [3512]	valid_0's huber: 5.79264
# [3516]	valid_0's huber: 5.79252
# [3520]	valid_0's huber: 5.7924
# [3524]	valid_0's huber: 5.79226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3528]	valid_0's huber: 5.79214
# [3532]	valid_0's huber: 5.79203
# [3536]	valid_0's huber: 5.79192
# [3540]	valid_0's huber: 5.79176
# [3544]	valid_0's huber: 5.79164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3548]	valid_0's huber: 5.79154
# [3552]	valid_0's huber: 5.79144
# [3556]	valid_0's huber: 5.79129
# [3560]	valid_0's huber: 5.79116
# [3564]	valid_0's huber: 5.79102
# [3568]	valid_0's huber: 5.79085
# [3572]	valid_0's huber: 5.7907
# [3576]	valid_0's huber: 5.79055
# [3580]	valid_0's huber: 5.79045
# [3584]	valid_0's huber: 5.79032
# [3588]	valid_0's huber: 5.79022
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3592]	valid_0's huber: 5.79004
# [3596]	valid_0's huber: 5.78993
# [3600]	valid_0's huber: 5.78982
# [3604]	valid_0's huber: 5.78971
# [3608]	valid_0's huber: 5.78951
# [3612]	valid_0's huber: 5.78938
# [3616]	valid_0's huber: 5.78924
# [3620]	valid_0's huber: 5.78909
# [3624]	valid_0's huber: 5.78896
# [3628]	valid_0's huber: 5.78881
# [3632]	valid_0's huber: 5.78867
# [3636]	valid_0's huber: 5.78854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3640]	valid_0's huber: 5.78842
# [3644]	valid_0's huber: 5.78823
# [3648]	valid_0's huber: 5.78814
# [3652]	valid_0's huber: 5.788
# [3656]	valid_0's huber: 5.78786
# [3660]	valid_0's huber: 5.78776
# [3664]	valid_0's huber: 5.78759
# [3668]	valid_0's huber: 5.78749
# [3672]	valid_0's huber: 5.78735
# [3676]	valid_0's huber: 5.7872
# [3680]	valid_0's huber: 5.78706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3684]	valid_0's huber: 5.78695
# [3688]	valid_0's huber: 5.78682
# [3692]	valid_0's huber: 5.78673
# [3696]	valid_0's huber: 5.7866
# [3700]	valid_0's huber: 5.78648
# [3704]	valid_0's huber: 5.78635
# [3708]	valid_0's huber: 5.78622
# [3712]	valid_0's huber: 5.78608
# [3716]	valid_0's huber: 5.78592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3720]	valid_0's huber: 5.78584
# [3724]	valid_0's huber: 5.78567
# [3728]	valid_0's huber: 5.78553
# [3732]	valid_0's huber: 5.78541
# [3736]	valid_0's huber: 5.7853
# [3740]	valid_0's huber: 5.78515
# [3744]	valid_0's huber: 5.78503
# [3748]	valid_0's huber: 5.7849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3752]	valid_0's huber: 5.78481
# [3756]	valid_0's huber: 5.78469
# [3760]	valid_0's huber: 5.78455
# [3764]	valid_0's huber: 5.78444
# [3768]	valid_0's huber: 5.78432
# [3772]	valid_0's huber: 5.78418
# [3776]	valid_0's huber: 5.78406
# [3780]	valid_0's huber: 5.78394
# [3784]	valid_0's huber: 5.78385
# [3788]	valid_0's huber: 5.78373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3792]	valid_0's huber: 5.78362
# [3796]	valid_0's huber: 5.78349
# [3800]	valid_0's huber: 5.78339
# [3804]	valid_0's huber: 5.78329
# [3808]	valid_0's huber: 5.78318
# [3812]	valid_0's huber: 5.78305
# [3816]	valid_0's huber: 5.78292
# [3820]	valid_0's huber: 5.78279
# [3824]	valid_0's huber: 5.78265
# [3828]	valid_0's huber: 5.78251
# [3832]	valid_0's huber: 5.78239
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3836]	valid_0's huber: 5.78226
# [3840]	valid_0's huber: 5.78213
# [3844]	valid_0's huber: 5.78202
# [3848]	valid_0's huber: 5.7819
# [3852]	valid_0's huber: 5.78178
# [3856]	valid_0's huber: 5.78168
# [3860]	valid_0's huber: 5.78152
# [3864]	valid_0's huber: 5.78141
# [3868]	valid_0's huber: 5.78128
# [3872]	valid_0's huber: 5.78115
# [3876]	valid_0's huber: 5.78101
# [3880]	valid_0's huber: 5.78083
# [3884]	valid_0's huber: 5.7807
# [3888]	valid_0's huber: 5.78059
# [3892]	valid_0's huber: 5.78047
# [3896]	valid_0's huber: 5.78032
# [3900]	valid_0's huber: 5.78019
# [3904]	valid_0's huber: 5.78004
# [3908]	valid_0's huber: 5.77993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3912]	valid_0's huber: 5.77981
# [3916]	valid_0's huber: 5.77967
# [3920]	valid_0's huber: 5.77955
# [3924]	valid_0's huber: 5.77938
# [3928]	valid_0's huber: 5.77926
# [3932]	valid_0's huber: 5.7791
# [3936]	valid_0's huber: 5.77897
# [3940]	valid_0's huber: 5.77886
# [3944]	valid_0's huber: 5.77869
# [3948]	valid_0's huber: 5.77856
# [3952]	valid_0's huber: 5.77847
# [3956]	valid_0's huber: 5.77838
# [3960]	valid_0's huber: 5.77829
# [3964]	valid_0's huber: 5.7782
# [3968]	valid_0's huber: 5.77808
# [3972]	valid_0's huber: 5.77794
# [3976]	valid_0's huber: 5.77781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3980]	valid_0's huber: 5.77771
# [3984]	valid_0's huber: 5.7776
# [3988]	valid_0's huber: 5.77753
# [3992]	valid_0's huber: 5.77735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3996]	valid_0's huber: 5.77726
# [4000]	valid_0's huber: 5.77713
# [4004]	valid_0's huber: 5.77699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4008]	valid_0's huber: 5.77691
# [4012]	valid_0's huber: 5.77678
# [4016]	valid_0's huber: 5.77663
# [4020]	valid_0's huber: 5.77651
# [4024]	valid_0's huber: 5.77638
# [4028]	valid_0's huber: 5.77623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4032]	valid_0's huber: 5.77612
# [4036]	valid_0's huber: 5.77602
# [4040]	valid_0's huber: 5.77585
# [4044]	valid_0's huber: 5.7757
# [4048]	valid_0's huber: 5.77547
# [4052]	valid_0's huber: 5.77534
# [4056]	valid_0's huber: 5.77524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4060]	valid_0's huber: 5.77513
# [4064]	valid_0's huber: 5.77497
# [4068]	valid_0's huber: 5.77482
# [4072]	valid_0's huber: 5.77467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4076]	valid_0's huber: 5.77458
# [4080]	valid_0's huber: 5.77443
# [4084]	valid_0's huber: 5.77427
# [4088]	valid_0's huber: 5.77408
# [4092]	valid_0's huber: 5.77396
# [4096]	valid_0's huber: 5.77382
# [4100]	valid_0's huber: 5.77366
# [4104]	valid_0's huber: 5.77352
# [4108]	valid_0's huber: 5.77341
# [4112]	valid_0's huber: 5.77332
# [4116]	valid_0's huber: 5.77319
# [4120]	valid_0's huber: 5.77305
# [4124]	valid_0's huber: 5.77289
# [4128]	valid_0's huber: 5.77278
# [4132]	valid_0's huber: 5.77267
# [4136]	valid_0's huber: 5.77255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4140]	valid_0's huber: 5.77243
# [4144]	valid_0's huber: 5.77232
# [4148]	valid_0's huber: 5.77221
# [4152]	valid_0's huber: 5.77211
# [4156]	valid_0's huber: 5.77195
# [4160]	valid_0's huber: 5.77182
# [4164]	valid_0's huber: 5.77169
# [4168]	valid_0's huber: 5.77152
# [4172]	valid_0's huber: 5.77141
# [4176]	valid_0's huber: 5.77126
# [4180]	valid_0's huber: 5.77115
# [4184]	valid_0's huber: 5.77101
# [4188]	valid_0's huber: 5.77089
# [4192]	valid_0's huber: 5.77079
# [4196]	valid_0's huber: 5.77066
# [4200]	valid_0's huber: 5.77057
# [4204]	valid_0's huber: 5.77045
# [4208]	valid_0's huber: 5.77032
# [4212]	valid_0's huber: 5.7702
# [4216]	valid_0's huber: 5.77001
# [4220]	valid_0's huber: 5.76988
# [4224]	valid_0's huber: 5.76978
# [4228]	valid_0's huber: 5.76965
# [4232]	valid_0's huber: 5.76954
# [4236]	valid_0's huber: 5.76942
# [4240]	valid_0's huber: 5.7693
# [4244]	valid_0's huber: 5.76921
# [4248]	valid_0's huber: 5.7691
# [4252]	valid_0's huber: 5.76896
# [4256]	valid_0's huber: 5.76885
# [4260]	valid_0's huber: 5.76877
# [4264]	valid_0's huber: 5.76867
# [4268]	valid_0's huber: 5.76858
# [4272]	valid_0's huber: 5.76841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4276]	valid_0's huber: 5.76829
# [4280]	valid_0's huber: 5.76815
# [4284]	valid_0's huber: 5.76799
# [4288]	valid_0's huber: 5.76789
# [4292]	valid_0's huber: 5.76778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4296]	valid_0's huber: 5.76766
# [4300]	valid_0's huber: 5.76752
# [4304]	valid_0's huber: 5.76741
# [4308]	valid_0's huber: 5.7673
# [4312]	valid_0's huber: 5.7672
# [4316]	valid_0's huber: 5.76705
# [4320]	valid_0's huber: 5.76694
# [4324]	valid_0's huber: 5.7668
# [4328]	valid_0's huber: 5.76665
# [4332]	valid_0's huber: 5.76654
# [4336]	valid_0's huber: 5.7664
# [4340]	valid_0's huber: 5.76628
# [4344]	valid_0's huber: 5.76617
# [4348]	valid_0's huber: 5.76603
# [4352]	valid_0's huber: 5.76594
# [4356]	valid_0's huber: 5.76581
# [4360]	valid_0's huber: 5.76573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4364]	valid_0's huber: 5.76563
# [4368]	valid_0's huber: 5.76553
# [4372]	valid_0's huber: 5.76537
# [4376]	valid_0's huber: 5.76522
# [4380]	valid_0's huber: 5.76512
# [4384]	valid_0's huber: 5.76496
# [4388]	valid_0's huber: 5.76481
# [4392]	valid_0's huber: 5.7647
# [4396]	valid_0's huber: 5.76462
# [4400]	valid_0's huber: 5.76449
# [4404]	valid_0's huber: 5.76439
# [4408]	valid_0's huber: 5.76428
# [4412]	valid_0's huber: 5.7642
# [4416]	valid_0's huber: 5.76407
# [4420]	valid_0's huber: 5.76392
# [4424]	valid_0's huber: 5.76378
# [4428]	valid_0's huber: 5.76365
# [4432]	valid_0's huber: 5.76355
# [4436]	valid_0's huber: 5.76343
# [4440]	valid_0's huber: 5.76332
# [4444]	valid_0's huber: 5.76322
# [4448]	valid_0's huber: 5.76312
# [4452]	valid_0's huber: 5.763
# [4456]	valid_0's huber: 5.76288
# [4460]	valid_0's huber: 5.76274
# [4464]	valid_0's huber: 5.76261
# [4468]	valid_0's huber: 5.76246
# [4472]	valid_0's huber: 5.76233
# [4476]	valid_0's huber: 5.76224
# [4480]	valid_0's huber: 5.76213
# [4484]	valid_0's huber: 5.76204
# [4488]	valid_0's huber: 5.76193
# [4492]	valid_0's huber: 5.76182
# [4496]	valid_0's huber: 5.76172
# [4500]	valid_0's huber: 5.76159
# [4504]	valid_0's huber: 5.76145
# [4508]	valid_0's huber: 5.76126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4512]	valid_0's huber: 5.76116
# [4516]	valid_0's huber: 5.76104
# [4520]	valid_0's huber: 5.76092
# [4524]	valid_0's huber: 5.7608
# [4528]	valid_0's huber: 5.76065
# [4532]	valid_0's huber: 5.76051
# [4536]	valid_0's huber: 5.76036
# [4540]	valid_0's huber: 5.76028
# [4544]	valid_0's huber: 5.76014
# [4548]	valid_0's huber: 5.76003
# [4552]	valid_0's huber: 5.75992
# [4556]	valid_0's huber: 5.75973
# [4560]	valid_0's huber: 5.75959
# [4564]	valid_0's huber: 5.75945
# [4568]	valid_0's huber: 5.75932
# [4572]	valid_0's huber: 5.75921
# [4576]	valid_0's huber: 5.75908
# [4580]	valid_0's huber: 5.75895
# [4584]	valid_0's huber: 5.75883
# [4588]	valid_0's huber: 5.75874
# [4592]	valid_0's huber: 5.75861
# [4596]	valid_0's huber: 5.75849
# [4600]	valid_0's huber: 5.75839
# [4604]	valid_0's huber: 5.75826
# [4608]	valid_0's huber: 5.75815
# [4612]	valid_0's huber: 5.75804
# [4616]	valid_0's huber: 5.75794
# [4620]	valid_0's huber: 5.75783
# [4624]	valid_0's huber: 5.75774
# [4628]	valid_0's huber: 5.75761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4632]	valid_0's huber: 5.75747
# [4636]	valid_0's huber: 5.75738
# [4640]	valid_0's huber: 5.75726
# [4644]	valid_0's huber: 5.75716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4648]	valid_0's huber: 5.75705
# [4652]	valid_0's huber: 5.75693
# [4656]	valid_0's huber: 5.75679
# [4660]	valid_0's huber: 5.75667
# [4664]	valid_0's huber: 5.75655
# [4668]	valid_0's huber: 5.75642
# [4672]	valid_0's huber: 5.7563
# [4676]	valid_0's huber: 5.75617
# [4680]	valid_0's huber: 5.75608
# [4684]	valid_0's huber: 5.75596
# [4688]	valid_0's huber: 5.75584
# [4692]	valid_0's huber: 5.75576
# [4696]	valid_0's huber: 5.75562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4700]	valid_0's huber: 5.75547
# [4704]	valid_0's huber: 5.75533
# [4708]	valid_0's huber: 5.75522
# [4712]	valid_0's huber: 5.75512
# [4716]	valid_0's huber: 5.75499
# [4720]	valid_0's huber: 5.75488
# [4724]	valid_0's huber: 5.75476
# [4728]	valid_0's huber: 5.75464
# [4732]	valid_0's huber: 5.75452
# [4736]	valid_0's huber: 5.75439
# [4740]	valid_0's huber: 5.75428
# [4744]	valid_0's huber: 5.75414
# [4748]	valid_0's huber: 5.75403
# [4752]	valid_0's huber: 5.75395
# [4756]	valid_0's huber: 5.75384
# [4760]	valid_0's huber: 5.75375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4764]	valid_0's huber: 5.75364
# [4768]	valid_0's huber: 5.7535
# [4772]	valid_0's huber: 5.75337
# [4776]	valid_0's huber: 5.75326
# [4780]	valid_0's huber: 5.75316
# [4784]	valid_0's huber: 5.75301
# [4788]	valid_0's huber: 5.75289
# [4792]	valid_0's huber: 5.75277
# [4796]	valid_0's huber: 5.75267
# [4800]	valid_0's huber: 5.75257
# [4804]	valid_0's huber: 5.75245
# [4808]	valid_0's huber: 5.75233
# [4812]	valid_0's huber: 5.75218
# [4816]	valid_0's huber: 5.75207
# [4820]	valid_0's huber: 5.75198
# [4824]	valid_0's huber: 5.75183
# [4828]	valid_0's huber: 5.75172
# [4832]	valid_0's huber: 5.75164
# [4836]	valid_0's huber: 5.7515
# [4840]	valid_0's huber: 5.75141
# [4844]	valid_0's huber: 5.7513
# [4848]	valid_0's huber: 5.75121
# [4852]	valid_0's huber: 5.75108
# [4856]	valid_0's huber: 5.75098
# [4860]	valid_0's huber: 5.75086
# [4864]	valid_0's huber: 5.75076
# [4868]	valid_0's huber: 5.75065
# [4872]	valid_0's huber: 5.75045
# [4876]	valid_0's huber: 5.75032
# [4880]	valid_0's huber: 5.75016
# [4884]	valid_0's huber: 5.75005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4888]	valid_0's huber: 5.74992
# [4892]	valid_0's huber: 5.74981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4896]	valid_0's huber: 5.7497
# [4900]	valid_0's huber: 5.74958
# [4904]	valid_0's huber: 5.74944
# [4908]	valid_0's huber: 5.74936
# [4912]	valid_0's huber: 5.74927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4916]	valid_0's huber: 5.74915
# [4920]	valid_0's huber: 5.74902
# [4924]	valid_0's huber: 5.7489
# [4928]	valid_0's huber: 5.74881
# [4932]	valid_0's huber: 5.74867
# [4936]	valid_0's huber: 5.74855
# [4940]	valid_0's huber: 5.74841
# [4944]	valid_0's huber: 5.74829
# [4948]	valid_0's huber: 5.74819
# [4952]	valid_0's huber: 5.74808
# [4956]	valid_0's huber: 5.74796
# [4960]	valid_0's huber: 5.74781
# [4964]	valid_0's huber: 5.74764
# [4968]	valid_0's huber: 5.7475
# [4972]	valid_0's huber: 5.74736
# [4976]	valid_0's huber: 5.74725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4980]	valid_0's huber: 5.74711
# [4984]	valid_0's huber: 5.74701
# [4988]	valid_0's huber: 5.74689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4992]	valid_0's huber: 5.74677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4996]	valid_0's huber: 5.74668
# ...
# [1924]	valid_0's huber: 3.94378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1928]	valid_0's huber: 3.94376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1932]	valid_0's huber: 3.9439
# [1936]	valid_0's huber: 3.94388
# [1940]	valid_0's huber: 3.94385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1944]	valid_0's huber: 3.94384
# [1948]	valid_0's huber: 3.94382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1952]	valid_0's huber: 3.94374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1956]	valid_0's huber: 3.94377
# [1960]	valid_0's huber: 3.94377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1964]	valid_0's huber: 3.9437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1968]	valid_0's huber: 3.94369
# [1972]	valid_0's huber: 3.94367
# [1976]	valid_0's huber: 3.94362
# [1980]	valid_0's huber: 3.94361
# [1984]	valid_0's huber: 3.94366
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1988]	valid_0's huber: 3.94361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1992]	valid_0's huber: 3.94358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1996]	valid_0's huber: 3.9436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's huber: 3.94361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2004]	valid_0's huber: 3.94372
# [2008]	valid_0's huber: 3.94368
# [2012]	valid_0's huber: 3.94363
# [2016]	valid_0's huber: 3.94367
# [2020]	valid_0's huber: 3.9436
# [2024]	valid_0's huber: 3.94356
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2028]	valid_0's huber: 3.94357
# [2032]	valid_0's huber: 3.94365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2036]	valid_0's huber: 3.94356
# [2040]	valid_0's huber: 3.94333
# [2044]	valid_0's huber: 3.9434
# [2048]	valid_0's huber: 3.94332
# [2052]	valid_0's huber: 3.94327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2056]	valid_0's huber: 3.9433
# [2060]	valid_0's huber: 3.94336
# [2064]	valid_0's huber: 3.94335
# [2068]	valid_0's huber: 3.94343
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2072]	valid_0's huber: 3.94349
# [2076]	valid_0's huber: 3.94343
# [2080]	valid_0's huber: 3.9435
# [2084]	valid_0's huber: 3.94341
# [2088]	valid_0's huber: 3.94336
# [2092]	valid_0's huber: 3.94332
# [2096]	valid_0's huber: 3.94335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2100]	valid_0's huber: 3.94336
# [2104]	valid_0's huber: 3.94331
# [2108]	valid_0's huber: 3.94328
# [2112]	valid_0's huber: 3.94317
# [2116]	valid_0's huber: 3.94314
# [2120]	valid_0's huber: 3.94311
# [2124]	valid_0's huber: 3.94307
# [2128]	valid_0's huber: 3.94307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2132]	valid_0's huber: 3.94306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2136]	valid_0's huber: 3.9431
# [2140]	valid_0's huber: 3.94312
# [2144]	valid_0's huber: 3.94316
# [2148]	valid_0's huber: 3.94309
# [2152]	valid_0's huber: 3.94307
# [2156]	valid_0's huber: 3.94305
# [2160]	valid_0's huber: 3.94315
# [2164]	valid_0's huber: 3.94308
# [2168]	valid_0's huber: 3.94319
# [2172]	valid_0's huber: 3.9432
# [2176]	valid_0's huber: 3.94323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2180]	valid_0's huber: 3.94325
# [2184]	valid_0's huber: 3.94319
# [2188]	valid_0's huber: 3.94317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2192]	valid_0's huber: 3.94309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2196]	valid_0's huber: 3.94319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2200]	valid_0's huber: 3.9432
# [2204]	valid_0's huber: 3.94322
# [2208]	valid_0's huber: 3.94327
# [2212]	valid_0's huber: 3.94326
# [2216]	valid_0's huber: 3.94325
# [2220]	valid_0's huber: 3.94329
# [2224]	valid_0's huber: 3.94333
# Early stopping, best iteration is:
# [2126]	valid_0's huber: 3.94303
# Model 4 best iteration: 2126
#
#
# Train the last model 5 on the entire dataset
# [LightGBM] [Warning] min_gain_to_split is set=0.04, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.04
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_gain_to_split is set=0.04, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.04
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 34758
# [LightGBM] [Info] Number of data points in the train set: 5237760, number of used features: 172
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 171 dense feature groups (859.16 MB) transferred to GPU in 0.744547 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score -0.047592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 48

# %% [markdown]
# # Submission

# %%
# Init
import optiver2023
env = optiver2023.make_env()
iter_test = env.iter_test()
"""
@nb.jit(nopython=False, parallel=True)
def prediction_func(predictions, test, y_min, y_max):
    predictions_zero_sum = zero_sum(predictions, test['bid_size'] + test['ask_size'])
    predictions_mean = predictions - np.mean(predictions)
    predictions = (predictions_zero_sum + predictions_mean) / 2
    
    # Clip the prediction
    clipped_predictions = np.clip(predictions, y_min, y_max)
    return clipped_predictions
"""

"""
@nb.jit(nopython=False, parallel=True)
def prediction_func(predictions, test, y_min, y_max):
    predictions_zero_sum = zero_sum(predictions, test['bid_size'] + test['ask_size'])
    clipped_predictions = np.clip(predictions_zero_sum, y_min, y_max)
    return clipped_predictions
"""

"""
@nb.jit(nopython=False, parallel=True)
def prediction_func(predictions, test, y_min, y_max):
    predictions = predictions - np.mean(predictions)
    clipped_predictions = np.clip(predictions, y_min, y_max)
    return clipped_predictions
"""
""""""
def weighted_average(a):
    w = []
    n = len(a)
    for j in range(1, n + 1):
        j = 2 if j == 1 else j
        w.append(1 / (2**(n + 1 - j)))
    return w


@nb.jit(nopython=False, parallel=True)
def zero_sum(prices, volumes):
    std_error = np.sqrt(volumes)
    step = np.sum(prices)/np.sum(std_error)
    out = prices-std_error*step
    return out


@nb.jit(nopython=False, parallel=True)
def weighted_predictions(predictions, th=1.2):
    predictions = np.column_stack(predictions)
    mean_predictions = np.mean(predictions, axis=1)
    median_predictions = np.median(predictions, axis=1)
    mask = np.abs(mean_predictions - median_predictions) > th
    final_predictions = np.where(mask, median_predictions, (mean_predictions * 0.6 + median_predictions * 0.40))    
    return final_predictions


# Init a counter
counter = 0

# To clip predictions
y_min, y_max = -64, 64

# Init an empty dataframe
cache = pd.DataFrame()

# Weights for each fold model
# model_weights = weighted_average(models)
model_weights = [1/len(models)] * len(models) 

for (test, revealed_targets, sample_prediction) in iter_test:       
    # Add data to the chache dataset
    cache = pd.concat([cache, test], ignore_index=True, axis=0)
    if counter > 0:
        cache = cache.groupby(['stock_id']).tail(21).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)
    
    # First iteration 
    if test.currently_scored.iloc[0]==False:
        sample_prediction['target'] = 0
        env.predict(sample_prediction)
        continue
        
    # Prepare the data
    features = feat_eng(cache)[-len(test):]
    features = features.drop(columns='date_id')
    
    predictions = []
    for model in models:
        predictions.append(model.predict(features))
    
    lgb_predictions = weighted_predictions(predictions)
    
    # Generate predictions for each model and calculate the weighted average
    # lgb_predictions = np.zeros(len(test))
    # for model, weight in zip(models, model_weights):
    #    lgb_predictions += weight * model.predict(features)
    predictions = lgb_predictions
    
    # Predict
    sample_prediction['target'] = zero_sum(predictions, test['bid_size'] + test['ask_size'])
    env.predict(sample_prediction)
        
    # Update the counter
    counter += 1
    
    # Run garbage collector
    gc.collect()
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
