# %%
import warnings
warnings.filterwarnings("ignore")
from itertools import combinations

import gc
import os
import sys
import json
import xgboost

import numpy as np
import pandas as pd
import numba as nb
import polars as pl

from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Functions

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print(f'Memory usage of dataframe is {start_mem:.2f} MB')
    
    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float32)
    
    end_mem = df.memory_usage().sum() / 1024**2
    print(f'Memory usage after optimization is: {end_mem:.2f} MB')
    
    decrease = 100 * (start_mem - end_mem) / start_mem
    print(f'Decreased by {decrease:.2f}%')
    
    return df


@nb.jit(nopython=False, parallel=True)
def compute_triplet_imbalance(df_values, comb_indices):
    num_rows = df_values.shape[0]
    num_combinations = len(comb_indices)
    imbalance_features = np.empty((num_rows, num_combinations))
    for i in range(num_combinations):
        a, b, c = comb_indices[i]
        for j in range(num_rows):
            max_val = max(df_values[j, a], df_values[j, b], df_values[j, c])
            min_val = min(df_values[j, a], df_values[j, b], df_values[j, c])
            mid_val = df_values[j, a] + df_values[j, b] + df_values[j, c] - min_val - max_val
            
            if mid_val == min_val:
                imbalance_features[j, i] = np.nan
            else:
                imbalance_features[j, i] = (max_val - mid_val) / (mid_val - min_val)
    return imbalance_features


@nb.jit(nopython=False,fastmath=True)
def calculate_triplet_imbalance(price, df):
    df_values = df[price].values
    comb_indices = [(price.index(a), price.index(b), price.index(c)) for a, b, c in combinations(price, 3)]
    features_array = compute_triplet_imbalance(df_values, comb_indices)
    columns = [f"{a}_{b}_{c}_imb2" for a, b, c in combinations(price, 3)]
    features = pd.DataFrame(features_array, columns=columns)
    return features


@nb.jit(nopython=False, parallel=True)
def calculate_weighted_wap(df):
    df["stock_weights"] = df["stock_id"].map(weights)
    df["weighted_wap"] = df["stock_weights"] * df["wap"]
    df['wap_momentum'] = df.groupby('stock_id')['weighted_wap'].pct_change(periods=6)
    return df


@nb.jit(nopython=False, parallel=True)
def calculate_rolling_mean_and_std_expressions(df):
    # Convert from pandas to Polars
    pl_df = pl.from_pandas(df)

    # Define the windows and columns for which you want to calculate the rolling statistics
    windows = [3, 5, 10]
    columns = ['ask_price', 'bid_price', 'ask_size', 'bid_size']

    # prepare the operations for each column and window
    group = ["stock_id"]
    expressions = []

    # Loop over each window and column to create the rolling mean and std expressions
    for window in windows:
        for col in columns:
            rolling_mean_expr = (
                pl.col(f"{col}_diff_{window}")
                .rolling_mean(window)
                .over(group)
                .alias(f'rolling_diff_{col}_{window}')
            )

            rolling_std_expr = (
                pl.col(f"{col}_diff_{window}")
                .rolling_std(window)
                .over(group)
                .alias(f'rolling_std_diff_{col}_{window}')
            )

            expressions.append(rolling_mean_expr)
            expressions.append(rolling_std_expr)

    # Run the operations using Polars' lazy API
    lazy_df = pl_df.lazy().with_columns(expressions)

    # Execute the lazy expressions and overwrite the pl_df variable
    pl_df = lazy_df.collect()

    # Convert back to pandas if necessary
    df = pl_df.to_pandas()
    
    return df

def feat_eng(df, epsilon=1e-8):   
    cols = [c for c in df.columns if c not in ['row_id', 'time_id', 'currently_scored']]
    df = df[cols]
    
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]
    prices = ['reference_price','far_price', 'near_price', 'ask_price', 'bid_price', 'wap']
    
    df = calculate_weighted_wap(df)
        
    # Adding some features
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  
    df["minute"] = df["seconds_in_bucket"] // 60
    df['time_to_market_close'] = 540 - df['seconds_in_bucket']
    
    df['imbalance_buy_flag'] = np.where(df['imbalance_buy_sell_flag']==1, 1, 0) 
    df['imbalance_sell_flag'] = np.where(df['imbalance_buy_sell_flag']==-1, 1, 0) 
    df['bid_plus_ask_sizes'] = df['bid_size'] + df['ask_size']
    df['imbalance_ratio'] = df.eval('imbalance_size / (matched_size + @epsilon)')
    
    df['imb_s1'] = df.eval('(bid_size - ask_size) / (bid_size + ask_size + @epsilon)')
    df['imb_s2'] = df.eval('(imbalance_size - matched_size) / (matched_size + imbalance_size + @epsilon)')
    
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["matched_imbalance"] = df.eval("(imbalance_size - matched_size)/(matched_size + imbalance_size)")
        
    df['ask_x_size'] = df.eval('ask_size * ask_price')
    df['bid_x_size'] = df.eval('bid_size * bid_price')
        
    df['ask_minus_bid'] = df['ask_x_size'] - df['bid_x_size'] 
    df["bid_size_over_ask_size"] = df["bid_size"].div(df["ask_size"])
    df["bid_price_over_ask_price"] = df["bid_price"].div(df["ask_price"])
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    df['relative_spread'] = (df['ask_price'] - df['bid_price']) / df['wap']
    df['harmonic_imbalance'] = df.eval('2 / ((1 / bid_size) + (1 / ask_size))')
    
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("(ask_price + bid_price) / 2")
    df['mid_price_movement'] = df['mid_price'].diff(periods=5).apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))
    df['mid_price*volume'] = df['mid_price_movement'] * df['volume']
    
    # Calculate diff features for specific columns
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap', 'ask_size', 'bid_size', 'weighted_wap', 'price_spread']:
        for window in [2, 3, 5, 10]:
            df[f"{col}_diff_{window}"] = df.groupby(["stock_id", "date_id"])[col].diff(window)
            
    df = calculate_rolling_mean_and_std_expressions(df)
            
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap']:
        df[f"{col}_gain"] = df[f"{col}_diff_{window}"].where(df[f"{col}_diff_{window}"] > 0, 0)
        df[f"{col}_loss"] = df[f"{col}_diff_{window}"].where(df[f"{col}_diff_{window}"] < 0, 0)
        df[f"{col}_gain_avg"] = df[f"{col}_gain"].rolling(window=5).mean()
        df[f"{col}_loss_avg"] = df[f"{col}_loss"].rolling(window=5).mean()
                    
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap']:
        df[f"{col}_cummax"] = df.groupby(["stock_id", "date_id"])[col].cummax() 
        df[f"{col}_cummin"] = df.groupby(["stock_id", "date_id"])[col].cummin() 
        df[f"{col}_min_max_norm"] = df.eval(f'({col} - {col}_cummin) / ({col}_cummax - {col}_cummin)')
        
    columns_to_keep = [col for col in df.columns if 'cummax' not in col]
    df = df[columns_to_keep]
    columns_to_keep = [col for col in df.columns if 'cummin' not in col]
    df = df[columns_to_keep]
        
    # Bollinger Bands 
    periods = [3, 5, 7, 9]
    for col in ['imb_s1', 'ask_price', 'bid_price', 'wap']:
        grouped = df.groupby(["stock_id", "date_id"])[col]
        for p in periods: 
            grouped_std = grouped.rolling(window=p).std().reset_index(drop=True)            
            df[f"{col}_bollinger_upper_{p}"] = df[f"{col}"] + 2 * grouped_std
            df[f"{col}_bollinger_lower_{p}"] = df[f"{col}"] - 2 * grouped_std
            
    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance(c, df)
        df[triplet_feature.columns] = triplet_feature.values
        
    for c in combinations(prices, 2):
        df[f'{c[0]}_minus_{c[1]}'] = df[f'{c[0]}'] - df[f'{c[1]}']
        df[f'{c[0]}_{c[1]}_imb'] = df.eval(f'({c[0]} - {c[1]}) / ({c[0]} + {c[1]} + @epsilon)')
        df[f'{c[0]}_{c[1]}_urgency'] = df[f'{c[0]}_minus_{c[1]}'] * df['imb_s1']
    
    columns_to_keep = [col for col in df.columns if 'minus' not in col]
    df = df[columns_to_keep]
    
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
        
    for window in [3,5,10]:
        df[f'price_change_diff_{window}'] = df[f'bid_price_diff_{window}'] - df[f'ask_price_diff_{window}']
        df[f'size_change_diff_{window}'] = df[f'bid_size_diff_{window}'] - df[f'ask_size_diff_{window}']
        
    # Add other features              
    for i in range(len(prices)-1):
        p1 = prices[i]
        for j in range(i+1, len(prices)):
            p2 = prices[j]
            df[f'{p1}_{p2}_pct_change'] = ((df[p1] - df[p2]) / (df[p2] + epsilon)) * 100
            
    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())
        
    df['high_volume'] = np.where(df['bid_plus_ask_sizes'] > df['global_median_vol'], 1, 0) 
    
    # Reduce memory usage
    df = reduce_mem_usage(df)
    
    # Run garbage collector
    gc.collect()
    return df

weights = [
    0.004, 0.001, 0.002, 0.006, 0.004, 0.004, 0.002, 0.006, 0.006, 0.002, 0.002, 0.008,
    0.006, 0.002, 0.008, 0.006, 0.002, 0.006, 0.004, 0.002, 0.004, 0.001, 0.006, 0.004,
    0.002, 0.002, 0.004, 0.002, 0.004, 0.004, 0.001, 0.001, 0.002, 0.002, 0.006, 0.004,
    0.004, 0.004, 0.006, 0.002, 0.002, 0.04 , 0.002, 0.002, 0.004, 0.04 , 0.002, 0.001,
    0.006, 0.004, 0.004, 0.006, 0.001, 0.004, 0.004, 0.002, 0.006, 0.004, 0.006, 0.004,
    0.006, 0.004, 0.002, 0.001, 0.002, 0.004, 0.002, 0.008, 0.004, 0.004, 0.002, 0.004,
    0.006, 0.002, 0.004, 0.004, 0.002, 0.004, 0.004, 0.004, 0.001, 0.002, 0.002, 0.008,
    0.02 , 0.004, 0.006, 0.002, 0.02 , 0.002, 0.002, 0.006, 0.004, 0.002, 0.001, 0.02,
    0.006, 0.001, 0.002, 0.004, 0.001, 0.002, 0.006, 0.006, 0.004, 0.006, 0.001, 0.002,
    0.004, 0.006, 0.006, 0.001, 0.04 , 0.006, 0.002, 0.004, 0.002, 0.002, 0.006, 0.002,
    0.002, 0.004, 0.006, 0.006, 0.002, 0.002, 0.008, 0.006, 0.004, 0.002, 0.006, 0.002,
    0.004, 0.006, 0.002, 0.004, 0.001, 0.004, 0.002, 0.004, 0.008, 0.006, 0.008, 0.002,
    0.004, 0.002, 0.001, 0.004, 0.004, 0.004, 0.006, 0.008, 0.004, 0.001, 0.001, 0.002,
    0.006, 0.004, 0.001, 0.002, 0.006, 0.004, 0.006, 0.008, 0.002, 0.002, 0.004, 0.002,
    0.04 , 0.002, 0.002, 0.004, 0.002, 0.002, 0.006, 0.02 , 0.004, 0.002, 0.006, 0.02,
    0.001, 0.002, 0.006, 0.004, 0.006, 0.004, 0.004, 0.004, 0.004, 0.002, 0.004, 0.04,
    0.002, 0.008, 0.002, 0.004, 0.001, 0.004, 0.006, 0.004,
]
weights = {int(k):v for k,v in enumerate(weights)}


def zero_sum(prices, volumes):
    std_error = np.sqrt(volumes)
    step = np.sum(prices)/np.sum(std_error)
    out = prices-std_error*step
    return out


def weighted_average(a):
    w = []
    n = len(a)
    for j in range(1, n + 1):
        j = 2 if j == 1 else j
        w.append(1 / (2**(n + 1 - j)))
    return w

# %% [markdown]
# # Dataset

# %%
# Load the dataset
train = pd.read_csv('/kaggle/input/optiver-trading-at-the-close/train.csv')

# Drop nan on target column
train.dropna(subset=['target'], inplace=True)

global_stock_id_feats = {
        "median_vol": train.groupby("stock_id")["bid_size"].median() + train.groupby("stock_id")["ask_size"].median(),
        "std_size": train.groupby("stock_id")["bid_size"].std() + train.groupby("stock_id")["ask_size"].std(),
        "ptp_size": train.groupby("stock_id")["bid_size"].max() - train.groupby("stock_id")["bid_size"].min(),
        "median_price": train.groupby("stock_id")["bid_price"].median() + train.groupby("stock_id")["ask_price"].median(),
        "std_price": train.groupby("stock_id")["bid_price"].std() + train.groupby("stock_id")["ask_price"].std(),
        "ptp_price": train.groupby("stock_id")["bid_price"].max() - train.groupby("stock_id")["ask_price"].min()
}

# Run garbage collector
gc.collect()

# Drop other relevant nan
train.dropna(subset=['bid_price', 'ask_price'], inplace=True)

# Reset the index
train.reset_index(drop=True)

# Apply features engineering
train = feat_eng(train)

# Get X ed Y
y = train['target']
X = train.drop(columns='target')

# Get date ids
date_ids = X['date_id'].values
X = X.drop(columns='date_id')

# Get feature names
feature_name = list(X.columns)

# Run garbage collector
gc.collect()
# Out:
# Memory usage of dataframe is 9031.17 MB
# Memory usage after optimization is: 2707.35 MB
# Decreased by 70.02%
# 0

# %% [markdown]
# # Model

# %%
num_folds = 5
fold_size = 480 // num_folds
gap = 5

stopping_rounds = 128
log_evaluation_periods = 2

xgboost_params = {
    'n_estimators': 6400,
    'booster': 'gbtree',
    'device': 'cuda',
    'verbosity': 2, 
    'learning_rate': 0.0085,
    'max_depth': 16,
    'subsample': 0.75,
    'colsample_bytree': 0.80,
    #'sampling_method': 'gradient_based', # 'gradient_based'
    'tree_method': 'hist',
    'grow_policy': 'depthwise',
    'max_leaves': 256,
    'max_bin': 3800,
    'objective':'reg:absoluteerror', 
    'reg_lambda': 0.00001,
    'reg_alpha': 0.00001
}

# Define lists
models = []
scores = []

# Run garbage collector
gc.collect()

# Loop over data
for i in range(num_folds):
    print(f"\n\nFold {i+1} Model Training")
    start = i * fold_size
    end = start + fold_size
    if i < num_folds - 1:  # No need to purge after the last fold
        purged_start = end - 2
        purged_end = end + gap + 2
        train_indices = (date_ids >= start) & (date_ids < purged_start) | (date_ids > purged_end)
    else:
        train_indices = (date_ids >= start) & (date_ids < end)
    
    val_indices = (date_ids >= end) & (date_ids < end + fold_size)
    
    # Get the data for the current fold
    X_fold_train = X[train_indices]
    y_fold_train = y[train_indices]
    X_fold_valid = X[val_indices]
    y_fold_valid = y[val_indices]
    
    # Define a Xgboost regressor model for the current fold
    xgboost_model = XGBRegressor(**xgboost_params)
    
    # Train the Xgboost model for the current fold
    xgboost_model.fit(
        X_fold_train[feature_name],
        y_fold_train,
        eval_set=[(X_fold_valid[feature_name], y_fold_valid)],
        callbacks=[
            xgboost.callback.EvaluationMonitor(period=log_evaluation_periods),
            xgboost.callback.EarlyStopping(rounds=stopping_rounds)
        ]
    )
    
    # Fill the model list
    models.append(xgboost_model)
        
    # Free up memory by deleting fold specific variables
    del X_fold_train, y_fold_train, X_fold_valid, y_fold_valid
    
    # Run garbage collector
    gc.collect()

# Calculate the average best iteration from all regular folds
average_best_iteration = int(np.mean([model.best_iteration for model in models]))

# Update the lgb_params with the average best iteration
final_model_params = xgboost_params.copy()
# final_model_params['n_estimators'] = average_best_iteration

print(f"\nTraining final model with average best iteration: {average_best_iteration}")

# Train the final model on the entire dataset
final_model = XGBRegressor(**final_model_params)
final_model.fit(
    X[feature_name],
    y,
    callbacks=[
        xgboost.callback.EvaluationMonitor(period=log_evaluation_periods),
    ],
)

# Append the final model to the list of models
models.append(final_model)

# Run garbage collector
gc.collect()
# Out:
# Fold 1 Model Training
# [0]	validation_0-mae:7.24094
# [0]	validation_0-mae:7.24094
# [1]	validation_0-mae:7.23853
# [2]	validation_0-mae:7.23614
# [2]	validation_0-mae:7.23614
# [3]	validation_0-mae:7.23377
# [4]	validation_0-mae:7.23145
# [4]	validation_0-mae:7.23145
# [5]	validation_0-mae:7.22922
# [6]	validation_0-mae:7.22704
# [6]	validation_0-mae:7.22704
# [7]	validation_0-mae:7.22483
# [8]	validation_0-mae:7.22260
# [8]	validation_0-mae:7.22260
# [9]	validation_0-mae:7.22044
# [10]	validation_0-mae:7.21832
# [10]	validation_0-mae:7.21832
# [11]	validation_0-mae:7.21624
# [12]	validation_0-mae:7.21422
# [12]	validation_0-mae:7.21422
# [13]	validation_0-mae:7.21217
# [14]	validation_0-mae:7.21015
# [239]	validation_0-mae:7.05329
# [240]	validation_0-mae:7.05306
# [240]	validation_0-mae:7.05306
# [241]	validation_0-mae:7.05282
# [242]	validation_0-mae:7.05259
# [242]	validation_0-mae:7.05259
# [243]	validation_0-mae:7.05238
# [244]	validation_0-mae:7.05215
# [244]	validation_0-mae:7.05215
# [245]	validation_0-mae:7.05191
# [246]	validation_0-mae:7.05168
# [246]	validation_0-mae:7.05168
# [247]	validation_0-mae:7.05143
# [248]	validation_0-mae:7.05119
# [248]	validation_0-mae:7.05119
# [249]	validation_0-mae:7.05096
# [250]	validation_0-mae:7.05075
# [250]	validation_0-mae:7.05075
# [251]	validation_0-mae:7.05053
# [252]	validation_0-mae:7.05030
# [252]	validation_0-mae:7.05030
# [253]	validation_0-mae:7.05011
# [254]	validation_0-mae:7.04990
# [254]	validation_0-mae:7.04990
# [255]	validation_0-mae:7.04967
# [256]	validation_0-mae:7.04945
# [256]	validation_0-mae:7.04945
# [257]	validation_0-mae:7.04924
# [258]	validation_0-mae:7.04903
# [258]	validation_0-mae:7.04903
# [259]	validation_0-mae:7.04883
# [260]	validation_0-mae:7.04863
# [260]	validation_0-mae:7.04863
# [261]	validation_0-mae:7.04842
# [262]	validation_0-mae:7.04822
# [262]	validation_0-mae:7.04822
# [263]	validation_0-mae:7.04800
# [264]	validation_0-mae:7.04782
# [264]	validation_0-mae:7.04782
# [265]	validation_0-mae:7.04763
# [266]	validation_0-mae:7.04742
# [266]	validation_0-mae:7.04742
# [267]	validation_0-mae:7.04721
# [268]	validation_0-mae:7.04702
# [268]	validation_0-mae:7.04702
# [269]	validation_0-mae:7.04682
# [270]	validation_0-mae:7.04664
# [270]	validation_0-mae:7.04664
# [271]	validation_0-mae:7.04643
# [272]	validation_0-mae:7.04618
# [272]	validation_0-mae:7.04618
# [273]	validation_0-mae:7.04599
# [274]	validation_0-mae:7.04579
# [274]	validation_0-mae:7.04579
# [275]	validation_0-mae:7.04558
# [276]	validation_0-mae:7.04540
# [276]	validation_0-mae:7.04540
# [277]	validation_0-mae:7.04522
# [278]	validation_0-mae:7.04503
# [278]	validation_0-mae:7.04503
# [279]	validation_0-mae:7.04483
# [280]	validation_0-mae:7.04465
# [280]	validation_0-mae:7.04465
# [281]	validation_0-mae:7.04446
# [282]	validation_0-mae:7.04428
# [282]	validation_0-mae:7.04428
# [283]	validation_0-mae:7.04410
# [284]	validation_0-mae:7.04389
# [284]	validation_0-mae:7.04389
# [285]	validation_0-mae:7.04370
# [286]	validation_0-mae:7.04349
# [286]	validation_0-mae:7.04349
# [287]	validation_0-mae:7.04330
# [288]	validation_0-mae:7.04312
# [288]	validation_0-mae:7.04312
# [289]	validation_0-mae:7.04293
# [290]	validation_0-mae:7.04273
# [290]	validation_0-mae:7.04273
# [291]	validation_0-mae:7.04255
# [292]	validation_0-mae:7.04236
# [292]	validation_0-mae:7.04236
# [293]	validation_0-mae:7.04219
# [294]	validation_0-mae:7.04203
# [294]	validation_0-mae:7.04203
# [295]	validation_0-mae:7.04184
# [296]	validation_0-mae:7.04165
# [296]	validation_0-mae:7.04165
# [297]	validation_0-mae:7.04148
# [298]	validation_0-mae:7.04130
# [298]	validation_0-mae:7.04130
# [299]	validation_0-mae:7.04112
# [300]	validation_0-mae:7.04094
# [300]	validation_0-mae:7.04094
# [301]	validation_0-mae:7.04075
# [302]	validation_0-mae:7.04057
# [302]	validation_0-mae:7.04057
# [303]	validation_0-mae:7.04040
# [304]	validation_0-mae:7.04023
# [304]	validation_0-mae:7.04023
# [305]	validation_0-mae:7.04006
# [306]	validation_0-mae:7.03988
# [306]	validation_0-mae:7.03988
# [307]	validation_0-mae:7.03971
# [308]	validation_0-mae:7.03957
# [308]	validation_0-mae:7.03957
# [309]	validation_0-mae:7.03936
# [310]	validation_0-mae:7.03920
# [310]	validation_0-mae:7.03920
# [311]	validation_0-mae:7.03904
# [312]	validation_0-mae:7.03886
# [312]	validation_0-mae:7.03886
# [313]	validation_0-mae:7.03868
# [314]	validation_0-mae:7.03853
# [314]	validation_0-mae:7.03853
# [315]	validation_0-mae:7.03834
# [316]	validation_0-mae:7.03816
# [316]	validation_0-mae:7.03816
# [317]	validation_0-mae:7.03799
# [318]	validation_0-mae:7.03784
# [318]	validation_0-mae:7.03784
# [319]	validation_0-mae:7.03767
# [320]	validation_0-mae:7.03751
# [320]	validation_0-mae:7.03751
# [321]	validation_0-mae:7.03733
# [322]	validation_0-mae:7.03717
# [322]	validation_0-mae:7.03717
# [323]	validation_0-mae:7.03701
# [324]	validation_0-mae:7.03685
# [324]	validation_0-mae:7.03685
# [325]	validation_0-mae:7.03670
# [326]	validation_0-mae:7.03655
# [326]	validation_0-mae:7.03655
# [327]	validation_0-mae:7.03638
# [328]	validation_0-mae:7.03622
# [328]	validation_0-mae:7.03622
# [329]	validation_0-mae:7.03608
# [330]	validation_0-mae:7.03591
# [330]	validation_0-mae:7.03591
# [331]	validation_0-mae:7.03573
# [332]	validation_0-mae:7.03558
# [332]	validation_0-mae:7.03558
# [333]	validation_0-mae:7.03539
# [334]	validation_0-mae:7.03522
# [334]	validation_0-mae:7.03522
# [335]	validation_0-mae:7.03505
# [336]	validation_0-mae:7.03486
# [336]	validation_0-mae:7.03486
# [337]	validation_0-mae:7.03469
# [338]	validation_0-mae:7.03454
# [338]	validation_0-mae:7.03454
# [339]	validation_0-mae:7.03440
# [340]	validation_0-mae:7.03424
# [340]	validation_0-mae:7.03424
# [341]	validation_0-mae:7.03408
# [342]	validation_0-mae:7.03394
# [342]	validation_0-mae:7.03394
# [343]	validation_0-mae:7.03380
# [344]	validation_0-mae:7.03363
# [344]	validation_0-mae:7.03363
# [345]	validation_0-mae:7.03346
# [346]	validation_0-mae:7.03331
# [346]	validation_0-mae:7.03331
# [347]	validation_0-mae:7.03316
# [348]	validation_0-mae:7.03299
# [348]	validation_0-mae:7.03299
# [349]	validation_0-mae:7.03281
# [350]	validation_0-mae:7.03265
# [350]	validation_0-mae:7.03265
# [575]	validation_0-mae:7.00251
# [576]	validation_0-mae:7.00239
# [576]	validation_0-mae:7.00239
# [577]	validation_0-mae:7.00228
# [578]	validation_0-mae:7.00219
# [578]	validation_0-mae:7.00219
# [579]	validation_0-mae:7.00209
# [580]	validation_0-mae:7.00198
# [580]	validation_0-mae:7.00198
# [581]	validation_0-mae:7.00182
# [582]	validation_0-mae:7.00168
# [582]	validation_0-mae:7.00168
# [583]	validation_0-mae:7.00156
# [584]	validation_0-mae:7.00144
# [584]	validation_0-mae:7.00144
# [585]	validation_0-mae:7.00128
# [586]	validation_0-mae:7.00119
# [586]	validation_0-mae:7.00119
# [587]	validation_0-mae:7.00109
# [588]	validation_0-mae:7.00095
# [588]	validation_0-mae:7.00095
# [589]	validation_0-mae:7.00085
# [590]	validation_0-mae:7.00077
# [590]	validation_0-mae:7.00077
# [591]	validation_0-mae:7.00061
# [592]	validation_0-mae:7.00050
# [592]	validation_0-mae:7.00050
# [593]	validation_0-mae:7.00038
# [594]	validation_0-mae:7.00032
# [594]	validation_0-mae:7.00032
# [595]	validation_0-mae:7.00020
# [596]	validation_0-mae:7.00008
# [596]	validation_0-mae:7.00008
# [597]	validation_0-mae:6.99998
# [598]	validation_0-mae:6.99985
# [598]	validation_0-mae:6.99985
# [599]	validation_0-mae:6.99976
# [600]	validation_0-mae:6.99964
# [600]	validation_0-mae:6.99964
# [601]	validation_0-mae:6.99951
# [602]	validation_0-mae:6.99939
# [602]	validation_0-mae:6.99939
# [603]	validation_0-mae:6.99932
# [604]	validation_0-mae:6.99919
# [604]	validation_0-mae:6.99919
# [605]	validation_0-mae:6.99910
# [606]	validation_0-mae:6.99900
# [606]	validation_0-mae:6.99900
# [607]	validation_0-mae:6.99891
# [608]	validation_0-mae:6.99883
# [608]	validation_0-mae:6.99883
# [609]	validation_0-mae:6.99875
# [610]	validation_0-mae:6.99864
# [610]	validation_0-mae:6.99864
# [611]	validation_0-mae:6.99855
# [612]	validation_0-mae:6.99845
# [612]	validation_0-mae:6.99845
# [613]	validation_0-mae:6.99835
# [614]	validation_0-mae:6.99824
# [614]	validation_0-mae:6.99824
# [615]	validation_0-mae:6.99815
# [616]	validation_0-mae:6.99808
# [616]	validation_0-mae:6.99808
# [617]	validation_0-mae:6.99800
# [618]	validation_0-mae:6.99789
# [618]	validation_0-mae:6.99789
# [619]	validation_0-mae:6.99781
# [620]	validation_0-mae:6.99770
# [620]	validation_0-mae:6.99770
# [621]	validation_0-mae:6.99761
# [622]	validation_0-mae:6.99748
# [622]	validation_0-mae:6.99748
# [623]	validation_0-mae:6.99738
# [624]	validation_0-mae:6.99729
# [624]	validation_0-mae:6.99729
# [625]	validation_0-mae:6.99717
# [626]	validation_0-mae:6.99706
# [626]	validation_0-mae:6.99706
# [627]	validation_0-mae:6.99692
# [628]	validation_0-mae:6.99680
# [628]	validation_0-mae:6.99680
# [629]	validation_0-mae:6.99670
# [630]	validation_0-mae:6.99660
# [630]	validation_0-mae:6.99660
# [631]	validation_0-mae:6.99649
# [632]	validation_0-mae:6.99636
# [632]	validation_0-mae:6.99636
# [633]	validation_0-mae:6.99625
# [634]	validation_0-mae:6.99618
# [634]	validation_0-mae:6.99618
# [635]	validation_0-mae:6.99608
# [636]	validation_0-mae:6.99594
# [636]	validation_0-mae:6.99594
# [637]	validation_0-mae:6.99583
# [638]	validation_0-mae:6.99572
# [638]	validation_0-mae:6.99572
# [639]	validation_0-mae:6.99561
# [640]	validation_0-mae:6.99548
# [640]	validation_0-mae:6.99548
# [641]	validation_0-mae:6.99534
# [642]	validation_0-mae:6.99521
# [642]	validation_0-mae:6.99521
# [643]	validation_0-mae:6.99514
# [644]	validation_0-mae:6.99505
# [644]	validation_0-mae:6.99505
# [645]	validation_0-mae:6.99496
# [646]	validation_0-mae:6.99489
# [646]	validation_0-mae:6.99489
# [647]	validation_0-mae:6.99481
# [648]	validation_0-mae:6.99473
# [648]	validation_0-mae:6.99473
# [649]	validation_0-mae:6.99464
# [650]	validation_0-mae:6.99452
# [650]	validation_0-mae:6.99452
# [651]	validation_0-mae:6.99443
# [652]	validation_0-mae:6.99436
# [652]	validation_0-mae:6.99436
# [653]	validation_0-mae:6.99427
# [654]	validation_0-mae:6.99415
# [654]	validation_0-mae:6.99415
# [655]	validation_0-mae:6.99405
# [656]	validation_0-mae:6.99394
# [656]	validation_0-mae:6.99394
# [657]	validation_0-mae:6.99384
# [658]	validation_0-mae:6.99374
# [658]	validation_0-mae:6.99374
# [659]	validation_0-mae:6.99365
# [660]	validation_0-mae:6.99355
# [660]	validation_0-mae:6.99355
# [661]	validation_0-mae:6.99349
# [662]	validation_0-mae:6.99339
# [662]	validation_0-mae:6.99339
# [663]	validation_0-mae:6.99327
# [664]	validation_0-mae:6.99313
# [664]	validation_0-mae:6.99313
# [665]	validation_0-mae:6.99304
# [666]	validation_0-mae:6.99293
# [666]	validation_0-mae:6.99293
# [667]	validation_0-mae:6.99282
# [668]	validation_0-mae:6.99269
# [668]	validation_0-mae:6.99269
# [669]	validation_0-mae:6.99260
# [670]	validation_0-mae:6.99251
# [670]	validation_0-mae:6.99251
# [671]	validation_0-mae:6.99238
# [672]	validation_0-mae:6.99228
# [672]	validation_0-mae:6.99228
# [673]	validation_0-mae:6.99217
# [674]	validation_0-mae:6.99205
# [674]	validation_0-mae:6.99205
# [675]	validation_0-mae:6.99196
# [676]	validation_0-mae:6.99185
# [676]	validation_0-mae:6.99185
# [677]	validation_0-mae:6.99177
# [678]	validation_0-mae:6.99169
# [678]	validation_0-mae:6.99169
# [679]	validation_0-mae:6.99156
# [680]	validation_0-mae:6.99146
# [680]	validation_0-mae:6.99146
# [681]	validation_0-mae:6.99138
# [682]	validation_0-mae:6.99129
# [682]	validation_0-mae:6.99129
# [683]	validation_0-mae:6.99119
# [684]	validation_0-mae:6.99106
# [684]	validation_0-mae:6.99106
# [685]	validation_0-mae:6.99096
# [686]	validation_0-mae:6.99088
# [686]	validation_0-mae:6.99088
# [687]	validation_0-mae:6.99078
# [688]	validation_0-mae:6.99067
# [688]	validation_0-mae:6.99067
# [689]	validation_0-mae:6.99057
# [690]	validation_0-mae:6.99047
# [690]	validation_0-mae:6.99047
# [691]	validation_0-mae:6.99036
# [692]	validation_0-mae:6.99025
# [692]	validation_0-mae:6.99025
# [693]	validation_0-mae:6.99015
# [694]	validation_0-mae:6.99001
# [694]	validation_0-mae:6.99001
# [695]	validation_0-mae:6.98991
# [696]	validation_0-mae:6.98980
# [696]	validation_0-mae:6.98980
# [697]	validation_0-mae:6.98969
# [698]	validation_0-mae:6.98962
# [698]	validation_0-mae:6.98962
# [699]	validation_0-mae:6.98952
# [700]	validation_0-mae:6.98941
# [700]	validation_0-mae:6.98941
# [701]	validation_0-mae:6.98928
# [702]	validation_0-mae:6.98922
# [702]	validation_0-mae:6.98922
# [703]	validation_0-mae:6.98915
# [704]	validation_0-mae:6.98907
# [704]	validation_0-mae:6.98907
# [705]	validation_0-mae:6.98896
# [706]	validation_0-mae:6.98887
# [706]	validation_0-mae:6.98887
# [707]	validation_0-mae:6.98879
# [708]	validation_0-mae:6.98871
# [708]	validation_0-mae:6.98871
# [709]	validation_0-mae:6.98859
# [710]	validation_0-mae:6.98850
# [710]	validation_0-mae:6.98850
# [711]	validation_0-mae:6.98835
# [712]	validation_0-mae:6.98824
# [712]	validation_0-mae:6.98824
# [713]	validation_0-mae:6.98816
# [714]	validation_0-mae:6.98807
# [714]	validation_0-mae:6.98807
# [715]	validation_0-mae:6.98796
# [716]	validation_0-mae:6.98788
# [716]	validation_0-mae:6.98788
# [717]	validation_0-mae:6.98782
# [718]	validation_0-mae:6.98771
# [718]	validation_0-mae:6.98771
# [719]	validation_0-mae:6.98763
# [720]	validation_0-mae:6.98752
# [720]	validation_0-mae:6.98752
# [721]	validation_0-mae:6.98744
# [722]	validation_0-mae:6.98734
# [722]	validation_0-mae:6.98734
# [723]	validation_0-mae:6.98724
# [724]	validation_0-mae:6.98715
# [724]	validation_0-mae:6.98715
# [725]	validation_0-mae:6.98705
# [726]	validation_0-mae:6.98696
# [726]	validation_0-mae:6.98696
# [727]	validation_0-mae:6.98686
# [728]	validation_0-mae:6.98677
# [728]	validation_0-mae:6.98677
# [729]	validation_0-mae:6.98667
# [730]	validation_0-mae:6.98658
# [730]	validation_0-mae:6.98658
# [731]	validation_0-mae:6.98650
# [732]	validation_0-mae:6.98643
# [732]	validation_0-mae:6.98643
# [733]	validation_0-mae:6.98635
# [734]	validation_0-mae:6.98626
# [734]	validation_0-mae:6.98626
# [735]	validation_0-mae:6.98618
# [736]	validation_0-mae:6.98609
# [736]	validation_0-mae:6.98609
# [737]	validation_0-mae:6.98597
# [738]	validation_0-mae:6.98588
# [738]	validation_0-mae:6.98588
# [739]	validation_0-mae:6.98580
# [740]	validation_0-mae:6.98568
# [740]	validation_0-mae:6.98568
# [741]	validation_0-mae:6.98558
# [742]	validation_0-mae:6.98548
# [742]	validation_0-mae:6.98548
# [1990]	validation_0-mae:4.81030
# [1991]	validation_0-mae:4.81032
# [1992]	validation_0-mae:4.81030
# [1992]	validation_0-mae:4.81030
# [1993]	validation_0-mae:4.81028
# [1994]	validation_0-mae:4.81025
# [1994]	validation_0-mae:4.81025
# [1995]	validation_0-mae:4.81017
# [1996]	validation_0-mae:4.81020
# [1996]	validation_0-mae:4.81020
# [1997]	validation_0-mae:4.81020
# [1998]	validation_0-mae:4.81021
# [1998]	validation_0-mae:4.81021
# [1999]	validation_0-mae:4.81021
# [2000]	validation_0-mae:4.81020
# [2000]	validation_0-mae:4.81020
# [2001]	validation_0-mae:4.81022
# [2002]	validation_0-mae:4.81017
# [2002]	validation_0-mae:4.81017
# [2003]	validation_0-mae:4.81017
# [2004]	validation_0-mae:4.81017
# [2004]	validation_0-mae:4.81017
# [2005]	validation_0-mae:4.81012
# [2006]	validation_0-mae:4.81013
# [2006]	validation_0-mae:4.81013
# [2007]	validation_0-mae:4.81016
# [2008]	validation_0-mae:4.81018
# [2008]	validation_0-mae:4.81018
# [2009]	validation_0-mae:4.81016
# [2010]	validation_0-mae:4.81013
# [2010]	validation_0-mae:4.81013
# [2011]	validation_0-mae:4.81005
# [2012]	validation_0-mae:4.81011
# [2012]	validation_0-mae:4.81011
# [2013]	validation_0-mae:4.81018
# [2014]	validation_0-mae:4.81018
# [2014]	validation_0-mae:4.81018
# [2015]	validation_0-mae:4.81020
# [2016]	validation_0-mae:4.81024
# [2016]	validation_0-mae:4.81024
# [2017]	validation_0-mae:4.81022
# [2018]	validation_0-mae:4.81025
# [2018]	validation_0-mae:4.81025
# [2019]	validation_0-mae:4.81026
# [2020]	validation_0-mae:4.81023
# [2020]	validation_0-mae:4.81023
# [2021]	validation_0-mae:4.81019
# [2022]	validation_0-mae:4.81016
# [2022]	validation_0-mae:4.81016
# [2023]	validation_0-mae:4.81016
# [2024]	validation_0-mae:4.81015
# [2024]	validation_0-mae:4.81015
# [2025]	validation_0-mae:4.81014
# [2026]	validation_0-mae:4.81016
# [2026]	validation_0-mae:4.81016
# [2027]	validation_0-mae:4.81014
# [2028]	validation_0-mae:4.81017
# [2028]	validation_0-mae:4.81017
# [2029]	validation_0-mae:4.81016
# [2030]	validation_0-mae:4.81016
# [2030]	validation_0-mae:4.81016
# [2031]	validation_0-mae:4.81016
# [2032]	validation_0-mae:4.81022
# [2032]	validation_0-mae:4.81022
# [2033]	validation_0-mae:4.81018
# [2034]	validation_0-mae:4.81011
# [2034]	validation_0-mae:4.81011
# [2035]	validation_0-mae:4.81012
# [2036]	validation_0-mae:4.81013
# [2036]	validation_0-mae:4.81013
# [2037]	validation_0-mae:4.81014
# [2038]	validation_0-mae:4.81010
# [2038]	validation_0-mae:4.81010
# [2039]	validation_0-mae:4.81019
# [2040]	validation_0-mae:4.81018
# [2040]	validation_0-mae:4.81018
# [2041]	validation_0-mae:4.81015
# [2042]	validation_0-mae:4.81015
# [2042]	validation_0-mae:4.81015
# [2043]	validation_0-mae:4.81017
# [2044]	validation_0-mae:4.81023
# [2044]	validation_0-mae:4.81023
# [2045]	validation_0-mae:4.81024
# [2046]	validation_0-mae:4.81023
# [2046]	validation_0-mae:4.81023
# [2047]	validation_0-mae:4.81020
# [2048]	validation_0-mae:4.81018
# [2048]	validation_0-mae:4.81018
# [2049]	validation_0-mae:4.81018
# [2050]	validation_0-mae:4.81005
# [2050]	validation_0-mae:4.81005
# [2051]	validation_0-mae:4.81005
# [2052]	validation_0-mae:4.81004
# [2052]	validation_0-mae:4.81004
# [2053]	validation_0-mae:4.81001
# [2054]	validation_0-mae:4.80993
# [2054]	validation_0-mae:4.80993
# [2055]	validation_0-mae:4.80991
# [2056]	validation_0-mae:4.80989
# [2056]	validation_0-mae:4.80989
# [2057]	validation_0-mae:4.80989
# [2058]	validation_0-mae:4.80991
# [2058]	validation_0-mae:4.80991
# [2059]	validation_0-mae:4.80991
# [2060]	validation_0-mae:4.80990
# [2060]	validation_0-mae:4.80990
# [2061]	validation_0-mae:4.80995
# [2062]	validation_0-mae:4.80993
# [2062]	validation_0-mae:4.80993
# [2063]	validation_0-mae:4.80998
# [2064]	validation_0-mae:4.81000
# [2064]	validation_0-mae:4.81000
# [2065]	validation_0-mae:4.80996
# [2066]	validation_0-mae:4.80997
# [2066]	validation_0-mae:4.80997
# [2067]	validation_0-mae:4.80997
# [2068]	validation_0-mae:4.80999
# [2068]	validation_0-mae:4.80999
# [2069]	validation_0-mae:4.80992
# [2070]	validation_0-mae:4.80995
# [2070]	validation_0-mae:4.80995
# [2071]	validation_0-mae:4.81009
# [2072]	validation_0-mae:4.81009
# [2072]	validation_0-mae:4.81009
# [2073]	validation_0-mae:4.81008
# [2074]	validation_0-mae:4.81007
# [2074]	validation_0-mae:4.81007
# [2075]	validation_0-mae:4.81019
# [2076]	validation_0-mae:4.81023
# [2076]	validation_0-mae:4.81023
# [2077]	validation_0-mae:4.81025
# [2078]	validation_0-mae:4.81024
# [2078]	validation_0-mae:4.81024
# [2079]	validation_0-mae:4.81025
# [2080]	validation_0-mae:4.81023
# [2080]	validation_0-mae:4.81023
# [2081]	validation_0-mae:4.81024
# [2082]	validation_0-mae:4.81016
# [2082]	validation_0-mae:4.81016
# [2083]	validation_0-mae:4.81014
# [2084]	validation_0-mae:4.81014
# [2084]	validation_0-mae:4.81014
# [2085]	validation_0-mae:4.81011
# [2086]	validation_0-mae:4.81010
# [2086]	validation_0-mae:4.81010
# [2087]	validation_0-mae:4.81007
# [2088]	validation_0-mae:4.81003
# [2088]	validation_0-mae:4.81003
# [2089]	validation_0-mae:4.81000
# [2090]	validation_0-mae:4.80994
# [2090]	validation_0-mae:4.80994
# [2091]	validation_0-mae:4.80993
# [2092]	validation_0-mae:4.80996
# [2092]	validation_0-mae:4.80996
# [2093]	validation_0-mae:4.80996
# [2094]	validation_0-mae:4.80995
# [2094]	validation_0-mae:4.80995
# [2095]	validation_0-mae:4.80987
# [2096]	validation_0-mae:4.80988
# [2096]	validation_0-mae:4.80988
# [2097]	validation_0-mae:4.80991
# [2098]	validation_0-mae:4.80983
# [2098]	validation_0-mae:4.80983
# [2099]	validation_0-mae:4.80979
# [2100]	validation_0-mae:4.80974
# [2100]	validation_0-mae:4.80974
# [2101]	validation_0-mae:4.80969
# [2102]	validation_0-mae:4.80969
# [2102]	validation_0-mae:4.80969
# [2103]	validation_0-mae:4.80967
# [2104]	validation_0-mae:4.80963
# [2104]	validation_0-mae:4.80963
# [2105]	validation_0-mae:4.80966
# [2106]	validation_0-mae:4.80967
# [2106]	validation_0-mae:4.80967
# [2107]	validation_0-mae:4.80963
# [2108]	validation_0-mae:4.80966
# [2108]	validation_0-mae:4.80966
# [2109]	validation_0-mae:4.80956
# [2110]	validation_0-mae:4.80953
# [2110]	validation_0-mae:4.80953
# [2111]	validation_0-mae:4.80951
# [2112]	validation_0-mae:4.80953
# [2112]	validation_0-mae:4.80953
# [2113]	validation_0-mae:4.80954
# [2114]	validation_0-mae:4.80956
# [2114]	validation_0-mae:4.80956
# [2115]	validation_0-mae:4.80957
# [2116]	validation_0-mae:4.80957
# [2116]	validation_0-mae:4.80957
# [2117]	validation_0-mae:4.80958
# [2118]	validation_0-mae:4.80957
# [2118]	validation_0-mae:4.80957
# [2119]	validation_0-mae:4.80957
# [2120]	validation_0-mae:4.80956
# [2120]	validation_0-mae:4.80956
# [2121]	validation_0-mae:4.80953
# [2122]	validation_0-mae:4.80948
# [2122]	validation_0-mae:4.80948
# [2123]	validation_0-mae:4.80946
# [2124]	validation_0-mae:4.80947
# [2124]	validation_0-mae:4.80947
# [2125]	validation_0-mae:4.80953
# [2126]	validation_0-mae:4.80948
# [2126]	validation_0-mae:4.80948
# [2127]	validation_0-mae:4.80950
# [2128]	validation_0-mae:4.80945
# [2128]	validation_0-mae:4.80945
# [2129]	validation_0-mae:4.80943
# [2130]	validation_0-mae:4.80954
# [2130]	validation_0-mae:4.80954
# [2131]	validation_0-mae:4.80950
# [2132]	validation_0-mae:4.80951
# [2132]	validation_0-mae:4.80951
# [2133]	validation_0-mae:4.80948
# [2134]	validation_0-mae:4.80948
# [2134]	validation_0-mae:4.80948
# [2135]	validation_0-mae:4.80949
# [2136]	validation_0-mae:4.80950
# [2136]	validation_0-mae:4.80950
# [2137]	validation_0-mae:4.80951
# [2138]	validation_0-mae:4.80950
# [2138]	validation_0-mae:4.80950
# [2139]	validation_0-mae:4.80954
# [2140]	validation_0-mae:4.80949
# [2140]	validation_0-mae:4.80949
# [2141]	validation_0-mae:4.80949
# [2142]	validation_0-mae:4.80950
# [2142]	validation_0-mae:4.80950
# [2143]	validation_0-mae:4.80951
# [2144]	validation_0-mae:4.80949
# [2144]	validation_0-mae:4.80949
# [2145]	validation_0-mae:4.80949
# [2146]	validation_0-mae:4.80943
# [2146]	validation_0-mae:4.80943
# [2147]	validation_0-mae:4.80943
# [2148]	validation_0-mae:4.80935
# [2148]	validation_0-mae:4.80935
# [2149]	validation_0-mae:4.80934
# [2150]	validation_0-mae:4.80932
# [2150]	validation_0-mae:4.80932
# [2151]	validation_0-mae:4.80927
# [2152]	validation_0-mae:4.80931
# [2152]	validation_0-mae:4.80931
# [2153]	validation_0-mae:4.80931
# [2154]	validation_0-mae:4.80930
# [2154]	validation_0-mae:4.80930
# [2155]	validation_0-mae:4.80932
# [2156]	validation_0-mae:4.80934
# [2156]	validation_0-mae:4.80934
# [2157]	validation_0-mae:4.80935
# [2158]	validation_0-mae:4.80929
# [2158]	validation_0-mae:4.80929
# [2159]	validation_0-mae:4.80927
# [2160]	validation_0-mae:4.80928
# [2160]	validation_0-mae:4.80928
# [2161]	validation_0-mae:4.80932
# [2162]	validation_0-mae:4.80930
# [2162]	validation_0-mae:4.80930
# [2163]	validation_0-mae:4.80929
# [2164]	validation_0-mae:4.80931
# [2164]	validation_0-mae:4.80931
# [2165]	validation_0-mae:4.80932
# [2166]	validation_0-mae:4.80931
# [2166]	validation_0-mae:4.80931
# [2167]	validation_0-mae:4.80933
# [2168]	validation_0-mae:4.80933
# [2168]	validation_0-mae:4.80933
# [2169]	validation_0-mae:4.80931
# [2170]	validation_0-mae:4.80935
# [2170]	validation_0-mae:4.80935
# [2171]	validation_0-mae:4.80940
# [2172]	validation_0-mae:4.80938
# [2172]	validation_0-mae:4.80938
# [2173]	validation_0-mae:4.80937
# [2174]	validation_0-mae:4.80938
# [2174]	validation_0-mae:4.80938
# [2175]	validation_0-mae:4.80939
# [2176]	validation_0-mae:4.80941
# [2176]	validation_0-mae:4.80941
# [2177]	validation_0-mae:4.80940
# [2178]	validation_0-mae:4.80936
# [2178]	validation_0-mae:4.80936
# [2179]	validation_0-mae:4.80934
# [2180]	validation_0-mae:4.80936
# [2180]	validation_0-mae:4.80936
# [2181]	validation_0-mae:4.80939
# [2182]	validation_0-mae:4.80937
# [2182]	validation_0-mae:4.80937
# [2183]	validation_0-mae:4.80936
# [2184]	validation_0-mae:4.80938
# [2184]	validation_0-mae:4.80938
# [2185]	validation_0-mae:4.80937
# [2186]	validation_0-mae:4.80943
# [2186]	validation_0-mae:4.80943
# [2187]	validation_0-mae:4.80946
# [2188]	validation_0-mae:4.80947
# [2188]	validation_0-mae:4.80947
# [2189]	validation_0-mae:4.80948
# [2190]	validation_0-mae:4.80947
# [2190]	validation_0-mae:4.80947
# [2191]	validation_0-mae:4.80942
# [2192]	validation_0-mae:4.80941
# [2192]	validation_0-mae:4.80941
# [2193]	validation_0-mae:4.80940
# [2194]	validation_0-mae:4.80943
# [2194]	validation_0-mae:4.80943
# [2195]	validation_0-mae:4.80943
# [2196]	validation_0-mae:4.80943
# [2196]	validation_0-mae:4.80943
# [2197]	validation_0-mae:4.80944
# [2198]	validation_0-mae:4.80944
# [2198]	validation_0-mae:4.80944
# [2199]	validation_0-mae:4.80942
# [2200]	validation_0-mae:4.80941
# [2200]	validation_0-mae:4.80941
# [2201]	validation_0-mae:4.80944
# [2202]	validation_0-mae:4.80940
# [2202]	validation_0-mae:4.80940
# [2203]	validation_0-mae:4.80947
# [2204]	validation_0-mae:4.80946
# [2204]	validation_0-mae:4.80946
# [2205]	validation_0-mae:4.80949
# [2206]	validation_0-mae:4.80945
# [2206]	validation_0-mae:4.80945
# [2207]	validation_0-mae:4.80944
# [2208]	validation_0-mae:4.80945
# [2208]	validation_0-mae:4.80945
# [2209]	validation_0-mae:4.80946
# [2210]	validation_0-mae:4.80945
# [2210]	validation_0-mae:4.80945
# [2211]	validation_0-mae:4.80940
# [2212]	validation_0-mae:4.80939
# [2212]	validation_0-mae:4.80939
# [2213]	validation_0-mae:4.80940
# [2214]	validation_0-mae:4.80945
# [2214]	validation_0-mae:4.80945
# [2215]	validation_0-mae:4.80943
# [2216]	validation_0-mae:4.80946
# [2216]	validation_0-mae:4.80946
# [2217]	validation_0-mae:4.80945
# [2218]	validation_0-mae:4.80946
# [2218]	validation_0-mae:4.80946
# [2219]	validation_0-mae:4.80952
# [2220]	validation_0-mae:4.80952
# [2220]	validation_0-mae:4.80952
# [2221]	validation_0-mae:4.80957
# [2222]	validation_0-mae:4.80957
# [2222]	validation_0-mae:4.80957
# [2223]	validation_0-mae:4.80956
# [2224]	validation_0-mae:4.80955
# [2224]	validation_0-mae:4.80955
# [2225]	validation_0-mae:4.80955
# [2226]	validation_0-mae:4.80955
# [2226]	validation_0-mae:4.80955
# [2227]	validation_0-mae:4.80952
# [2228]	validation_0-mae:4.80952
# [2228]	validation_0-mae:4.80952
# [2229]	validation_0-mae:4.80955
# [2230]	validation_0-mae:4.80956
# [2230]	validation_0-mae:4.80956
# [2231]	validation_0-mae:4.80949
# [2232]	validation_0-mae:4.80952
# [2232]	validation_0-mae:4.80952
# [2233]	validation_0-mae:4.80952
# [2234]	validation_0-mae:4.80946
# [2234]	validation_0-mae:4.80946
# [2235]	validation_0-mae:4.80947
# [2236]	validation_0-mae:4.80944
# [2236]	validation_0-mae:4.80944
# [2237]	validation_0-mae:4.80941
# [2238]	validation_0-mae:4.80940
# [2238]	validation_0-mae:4.80940
# [2239]	validation_0-mae:4.80943
# [2240]	validation_0-mae:4.80946
# [2240]	validation_0-mae:4.80946
# [2241]	validation_0-mae:4.80951
# [2242]	validation_0-mae:4.80951
# [2242]	validation_0-mae:4.80951
# [2243]	validation_0-mae:4.80954
# [2244]	validation_0-mae:4.80951
# [2244]	validation_0-mae:4.80951
# [2245]	validation_0-mae:4.80950
# [2246]	validation_0-mae:4.80955
# [2246]	validation_0-mae:4.80955
# [2247]	validation_0-mae:4.80956
# [2248]	validation_0-mae:4.80953
# [2248]	validation_0-mae:4.80953
# [2249]	validation_0-mae:4.80954
# [2250]	validation_0-mae:4.80957
# [2250]	validation_0-mae:4.80957
# [2251]	validation_0-mae:4.80952
# [2252]	validation_0-mae:4.80944
# [2252]	validation_0-mae:4.80944
# [2253]	validation_0-mae:4.80945
# [2254]	validation_0-mae:4.80945
# [2254]	validation_0-mae:4.80945
# [2255]	validation_0-mae:4.80943
# [2256]	validation_0-mae:4.80942
# [2256]	validation_0-mae:4.80942
# [2257]	validation_0-mae:4.80944
# [2258]	validation_0-mae:4.80952
# [2258]	validation_0-mae:4.80952
# [2259]	validation_0-mae:4.80951
# [2260]	validation_0-mae:4.80948
# [2260]	validation_0-mae:4.80948
# [2261]	validation_0-mae:4.80941
# [2262]	validation_0-mae:4.80941
# [2262]	validation_0-mae:4.80941
# [2263]	validation_0-mae:4.80945
# [2264]	validation_0-mae:4.80942
# [2264]	validation_0-mae:4.80942
# [2265]	validation_0-mae:4.80948
# [2266]	validation_0-mae:4.80946
# [2266]	validation_0-mae:4.80946
# [2267]	validation_0-mae:4.80951
# [2268]	validation_0-mae:4.80952
# [2268]	validation_0-mae:4.80952
# [2269]	validation_0-mae:4.80954
# [2270]	validation_0-mae:4.80956
# [2270]	validation_0-mae:4.80956
# [2271]	validation_0-mae:4.80956
# [2272]	validation_0-mae:4.80955
# [2272]	validation_0-mae:4.80955
# [2273]	validation_0-mae:4.80951
# [2274]	validation_0-mae:4.80944
# [2274]	validation_0-mae:4.80944
# [2275]	validation_0-mae:4.80949
# [2276]	validation_0-mae:4.80954
# [2276]	validation_0-mae:4.80954
# [2277]	validation_0-mae:4.80954
# [2278]	validation_0-mae:4.80953
# [2278]	validation_0-mae:4.80953
# [2279]	validation_0-mae:4.80955
# [2279]	validation_0-mae:4.80955
#
# Training final model with average best iteration: 5549
# 1631

# %% [markdown]
# # Submission

# %%
# Init
import optiver2023
env = optiver2023.make_env()
iter_test = env.iter_test()

# Init a counter
counter = 0

# To clip predictions
y_min, y_max = -64, 64

# Init an empty dataframe
cache = pd.DataFrame()

# Weights for each fold model
# model_weights = [1/len(models)] * len(models) 
model_weights = weighted_average(models)

for (test, revealed_targets, sample_prediction) in iter_test:       
    # Add data to the chache dataset
    cache = pd.concat([cache, test], ignore_index=True, axis=0)
    if counter > 0:
        cache = cache.groupby(['stock_id']).tail(21).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)
        
    # First iteration 
    if test.currently_scored.iloc[0]==False:
        sample_prediction['target'] = 0
        env.predict(sample_prediction)
        continue

    # Prepare the data
    features = feat_eng(cache)[-len(test):]
    features = features.drop(columns='date_id')

    # Generate predictions for each model and calculate the weighted average
    lgb_predictions = np.zeros(len(test))
    for model, weight in zip(models, model_weights):
        lgb_predictions += weight * model.predict(features)

    # Zero sum
    #lgb_predictions = zero_sum(lgb_predictions, test['bid_size'] + test['ask_size'])
    
    lgb_predictions_zero_sum = zero_sum(lgb_predictions, test['bid_size'] + test['ask_size'])
    lgb_predictions_mean = lgb_predictions - np.mean(lgb_predictions)
    lgb_predictions = (lgb_predictions_zero_sum + lgb_predictions_mean) / 2
    
    # Clip the prediction
    clipped_predictions = np.clip(lgb_predictions, y_min, y_max)

    # Predict
    sample_prediction['target'] = clipped_predictions
    env.predict(sample_prediction)
    
    # Update the counter
    counter += 1
    
    # Run garbage collector
    gc.collect()
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
